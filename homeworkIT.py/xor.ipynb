# %%
# %pip install tensorflow numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tensorflow as tf
import numpy as np
from random import randint

# %%
model = None 

def generateInputs(num):
    inputs = np.random.randint(-10, 10, size = (num, 2)).tolist()
    return inputs 

def initModel(): # задаем в ней нашу модельБ наши данные которые в задании и обучаем быстренько -_-
    global model
    input = [[1, 0], [-1, 1], [-1, 1], [1, 1]]
    inputTensor = tf.constant(input, shape=(len(input), 2)) # имеет len(input) строк и 2 столбца
    output = [[1], [-1], [1], [-1]]
    outputTensor = tf.constant(output, shape=(len(output), 1)) # ожидаемые входные данные 
    testInput = generateInputs(10)
    testInputTensor = tf.constant(testInput, shape=(len(testInput), 2)) # количество строк равно длине testInput ну а столбцы 2
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Dense(units=2, activation='sigmoid', input_shape=(2,)))
    model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))
    model.compile(optimizer=tf.keras.optimizers.Adam(0.1), loss='mean_squared_error')
    model.fit(inputTensor, outputTensor, epochs=55, shuffle=True, callbacks=[LossHistoryCallback()])

class LossHistoryCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        loss = logs['loss']

data = []
lossHistory = []

testInput = generateInputs(10)

initModel()
# Out:
# Epoch 1/55
# 1/1 [==============================] - 1s 617ms/step - loss: 1.1737
# Epoch 2/55
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1176
# Epoch 3/55
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0747
# Epoch 4/55
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0437
# Epoch 5/55
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0222
# Epoch 6/55
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0074
# Epoch 7/55
# 1/1 [==============================] - 0s 6ms/step - loss: 0.9970
# Epoch 8/55
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9895
# Epoch 9/55
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9837
# Epoch 10/55
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9789
# Epoch 11/55
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9748
# Epoch 12/55
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9711
# Epoch 13/55
# ...
