# %%
# %pip install spacy nltk numpy scikit-learn
import spacy
import numpy as np 
from sklearn.feature_extraction.text import TfidfTransformer
from nltk import word_tokenize
spacy.load('ru_core_news_sm')
from nltk import word_tokenize
from nltk import SnowballStemmer
from nltk.corpus import stopwords
import math
import re
import collections
from collections import Counter
import nltk
# Out:
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
with open("57373677.txt") as file:
    text = file.read()

# %%
words = word_tokenize(text)
words
# Out:
# ['Живая',
#  'шляпа',
#  'Николай',
#  'Николаевич',
#  'Носов',
#  'Классика',
#  'нашего',
#  'детства',
#  'Рассказы',
#  ',',
#  'как',
#  'и',
#  'все',
#  'произведения',
#  'Николая',
#  'Носова',
#  ',',
#  'давно',
#  'стали',
#  'не',
#  'только',
#  'классикой',
#  ',',
#  'но',
#  'и',
#  ',',
#  'без',
#  'преувеличения',
#  ',',
#  'национальным',
#  'достоянием',
#  '.',
#  'В',
#  'нашей',
#  'стране',
#  'нет',
#  'ни',
#  'одного',
#  'человека',
#  ',',
#  'который',
#  'бы',
#  'не',
#  'читал',
#  'в',
#  'детстве',
#  'про',
#  'живую',
#  'шляпу',
#  'и',
#  'Мишкину',
#  'кашу',
#  ',',
#  'про',
#  'фантазёров',
#  'или',
#  'Бобика',
#  'в',
#  'гостях',
#  'у',
#  'Барбоса…',
#  'Герои',
#  'рассказов',
#  'Носова',
#  '–',
#  'такие',
#  'же',
#  'живые',
#  'и',
#  'настоящие',
#  ',',
#  'как',
#  'и',
#  'любой',
#  'соседский',
#  'мальчишка',
#  'или',
#  'девчонка',
#  '.',
#  'Они',
#  'так',
#  'же',
#  'учатся',
#  'в',
#  'школе',
#  ',',
# ...

# %%
nltk.download('stopwords')
stop = stopwords.words('russian')
stop
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Ustin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
# ...

# %%
token_fil = [token for token in words if token not in stop]
token_fil
# Out:
# ['Живая',
#  'шляпа',
#  'Николай',
#  'Николаевич',
#  'Носов',
#  'Классика',
#  'нашего',
#  'детства',
#  'Рассказы',
#  ',',
#  'произведения',
#  'Николая',
#  'Носова',
#  ',',
#  'давно',
#  'стали',
#  'классикой',
#  ',',
#  ',',
#  'преувеличения',
#  ',',
#  'национальным',
#  'достоянием',
#  '.',
#  'В',
#  'нашей',
#  'стране',
#  'одного',
#  'человека',
#  ',',
#  'который',
#  'читал',
#  'детстве',
#  'живую',
#  'шляпу',
#  'Мишкину',
#  'кашу',
#  ',',
#  'фантазёров',
#  'Бобика',
#  'гостях',
#  'Барбоса…',
#  'Герои',
#  'рассказов',
#  'Носова',
#  '–',
#  'такие',
#  'живые',
#  'настоящие',
#  ',',
#  'любой',
#  'соседский',
#  'мальчишка',
#  'девчонка',
#  '.',
#  'Они',
#  'учатся',
#  'школе',
#  ',',
#  'играют',
#  'проказничают',
#  ',',
#  'радуются',
#  'грустят',
#  ',',
#  'ссорятся',
#  'мирятся',
#  '.',
#  'С',
#  'детства',
#  'любимые',
#  'рассказы',
#  'Николая',
#  'Носова',
#  'прекрасно',
#  'проиллюстрированы',
#  'замечательными',
# ...

# %%
m = SnowballStemmer(language='russian')
tokinized = nltk.word_tokenize(text)
st = [m.stem(token_fil) for token_fil in tokinized]
st
# Out:
# ['жив',
#  'шляп',
#  'никола',
#  'николаевич',
#  'нос',
#  'классик',
#  'наш',
#  'детств',
#  'рассказ',
#  ',',
#  'как',
#  'и',
#  'все',
#  'произведен',
#  'никол',
#  'носов',
#  ',',
#  'давн',
#  'стал',
#  'не',
#  'тольк',
#  'классик',
#  ',',
#  'но',
#  'и',
#  ',',
#  'без',
#  'преувеличен',
#  ',',
#  'национальн',
#  'достоян',
#  '.',
#  'в',
#  'наш',
#  'стран',
#  'нет',
#  'ни',
#  'одн',
#  'человек',
#  ',',
#  'котор',
#  'бы',
#  'не',
#  'чита',
#  'в',
#  'детств',
#  'про',
#  'жив',
#  'шляп',
#  'и',
#  'мишкин',
#  'каш',
#  ',',
#  'про',
#  'фантазер',
#  'ил',
#  'бобик',
#  'в',
#  'гост',
#  'у',
#  'барбоса…',
#  'геро',
#  'рассказ',
#  'носов',
#  '–',
#  'так',
#  'же',
#  'жив',
#  'и',
#  'настоя',
#  ',',
#  'как',
#  'и',
#  'люб',
#  'соседск',
#  'мальчишк',
#  'ил',
#  'девчонк',
#  '.',
#  'он',
#  'так',
#  'же',
#  'учат',
#  'в',
#  'школ',
#  ',',
#  'игра',
#  'и',
#  'проказнича',
#  ',',
#  'так',
#  'же',
#  'рад',
# ...

# %%
with open("57373628.txt") as file:
    text2 = file.read()

# %%
words = word_tokenize(text2)
words
# Out:
# ['Фантазеры',
#  'Николай',
#  'Николаевич',
#  'Носов',
#  'Классика',
#  'нашего',
#  'детства',
#  'Весёлые',
#  'и',
#  'поучительные',
#  'рассказы',
#  'знаменитого',
#  'писателя',
#  'Николая',
#  'Носова',
#  'с',
#  'иллюстрациями',
#  'не',
#  'менее',
#  'знаменитого',
#  'художника',
#  'Германа',
#  'Огородникова',
#  'давно',
#  'стали',
#  'классикой',
#  '.',
#  'Их',
#  'знают',
#  'и',
#  'любят',
#  'миллионы',
#  'детей',
#  'в',
#  'нашей',
#  'стране',
#  '.',
#  'А',
#  'всё',
#  'потому',
#  ',',
#  'что',
#  'герои',
#  'этих',
#  'рассказов',
#  '–',
#  'такие',
#  'же',
#  'обычные',
#  'ребята',
#  ',',
#  'любознательные',
#  ',',
#  'искренние',
#  ',',
#  'честные',
#  ',',
#  'ценящие',
#  'дружбу',
#  '.',
#  'Они',
#  'никогда',
#  'не',
#  'скучают',
#  'и',
#  'всегда',
#  'заняты',
#  'каким-нибудь',
#  'интересным',
#  'делом',
#  '.',
#  'Николай',
#  'Николаевич',
#  'Носов',
#  'Фантазёры',
#  'Фантазеры',
#  'Мишутка',
#  'и',
#  'Стасик',
# ...

# %%
nltk.download('stopwords')
stop = stopwords.words('russian')
stop
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Ustin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
# ...

# %%
token_fil2 = [token for token in words if token not in stop]
token_fil2
# Out:
# ['Фантазеры',
#  'Николай',
#  'Николаевич',
#  'Носов',
#  'Классика',
#  'нашего',
#  'детства',
#  'Весёлые',
#  'поучительные',
#  'рассказы',
#  'знаменитого',
#  'писателя',
#  'Николая',
#  'Носова',
#  'иллюстрациями',
#  'менее',
#  'знаменитого',
#  'художника',
#  'Германа',
#  'Огородникова',
#  'давно',
#  'стали',
#  'классикой',
#  '.',
#  'Их',
#  'знают',
#  'любят',
#  'миллионы',
#  'детей',
#  'нашей',
#  'стране',
#  '.',
#  'А',
#  'всё',
#  ',',
#  'герои',
#  'этих',
#  'рассказов',
#  '–',
#  'такие',
#  'обычные',
#  'ребята',
#  ',',
#  'любознательные',
#  ',',
#  'искренние',
#  ',',
#  'честные',
#  ',',
#  'ценящие',
#  'дружбу',
#  '.',
#  'Они',
#  'скучают',
#  'заняты',
#  'каким-нибудь',
#  'интересным',
#  'делом',
#  '.',
#  'Николай',
#  'Николаевич',
#  'Носов',
#  'Фантазёры',
#  'Фантазеры',
#  'Мишутка',
#  'Стасик',
#  'сидели',
#  'саду',
#  'скамеечке',
#  'разговаривали',
#  '.',
#  'Только',
#  'разговаривали',
#  'просто',
#  ',',
# ...

# %%
m2 = SnowballStemmer(language='russian')
tokinized = nltk.word_tokenize(text2)
st2 = [m.stem(token_fil) for token_fil in tokinized]
st2
# Out:
# ['фантазер',
#  'никола',
#  'николаевич',
#  'нос',
#  'классик',
#  'наш',
#  'детств',
#  'весел',
#  'и',
#  'поучительн',
#  'рассказ',
#  'знаменит',
#  'писател',
#  'никол',
#  'носов',
#  'с',
#  'иллюстрац',
#  'не',
#  'мен',
#  'знаменит',
#  'художник',
#  'герма',
#  'огородников',
#  'давн',
#  'стал',
#  'классик',
#  '.',
#  'их',
#  'знают',
#  'и',
#  'люб',
#  'миллион',
#  'дет',
#  'в',
#  'наш',
#  'стран',
#  '.',
#  'а',
#  'все',
#  'пот',
#  ',',
#  'что',
#  'геро',
#  'эт',
#  'рассказ',
#  '–',
#  'так',
#  'же',
#  'обычн',
#  'ребят',
#  ',',
#  'любознательн',
#  ',',
#  'искрен',
#  ',',
#  'честн',
#  ',',
#  'ценя',
#  'дружб',
#  '.',
#  'он',
#  'никогд',
#  'не',
#  'скуча',
#  'и',
#  'всегд',
#  'занят',
#  'каким-нибуд',
#  'интересн',
#  'дел',
#  '.',
#  'никола',
#  'николаевич',
#  'нос',
#  'фантазер',
#  'фантазер',
#  'мишутк',
#  'и',
#  'стасик',
#  'сидел',
#  'в',
#  'сад',
#  'на',
#  'скамеечк',
#  'и',
#  'разговарива',
#  '.',
# ...

# %% [markdown]
# косинус первым со вторым

# %%
import math
from collections import Counter


# Создание вектора слов для текста
def create_word_vector(text):
    word_counts = Counter(text)
    vector = []
    for word in text:
        vector.append(word_counts[word])
    return vector

# Расчет косинусного сходства
def cosine_similarity(vector1, vector2):
    dot_product = sum(a * b for a, b in zip(vector1, vector2))
    magnitude1 = math.sqrt(sum(a ** 2 for a in vector1))
    magnitude2 = math.sqrt(sum(b ** 2 for b in vector2))
    return dot_product / (magnitude1 * magnitude2)

# Предобработка текстов
text = st
text2 = st2

# Создание векторов слов для текстов
vector1 = create_word_vector(text)
vector2 = create_word_vector(text2)

# Расчет косинусного сходства
similarity = cosine_similarity(vector1, vector2)

# Вывод результата
print("Косинусное сходство:", similarity)
# Out:
# Косинусное сходство: 0.3174492414646447

# %%
with open("Носов Николай. Незнайка на Луне (иллюстрации Генриха Валька) - royallib.com.txt") as file:
    text3 = file.read()

# %%
words = word_tokenize(text3)
words
# Out:
# ['Николай',
#  'Носов',
#  'НЕЗНАЙКА',
#  'НА',
#  'ЛУНЕ',
#  'РОМАН-СКАЗКА',
#  'Иллюстрации',
#  'Генриха',
#  'Валька',
#  'ЧАСТЬ',
#  'I',
#  'Глава',
#  'первая',
#  'КАК',
#  'ЗНАЙКА',
#  'ПОБЕДИЛ',
#  'ПРОФЕССОРА',
#  'ЗВЁЗДОЧКИНА',
#  'С',
#  'тех',
#  'пор',
#  'как',
#  'Незнайка',
#  'совершил',
#  'путешествие',
#  'в',
#  'Солнечный',
#  'город',
#  ',',
#  'прошло',
#  'два',
#  'с',
#  'половиной',
#  'года',
#  '.',
#  'Хотя',
#  'для',
#  'нас',
#  'с',
#  'вами',
#  'это',
#  'не',
#  'так',
#  'уж',
#  'много',
#  ',',
#  'но',
#  'для',
#  'маленьких',
#  'коротышек',
#  'два',
#  'с',
#  'половиной',
#  'года',
#  '—',
#  'срок',
#  'очень',
#  'большой',
#  '.',
#  'Наслушавшись',
#  'рассказов',
#  'Незнайки',
#  ',',
#  'Кнопочки',
#  'и',
#  'Пачкули',
#  'Пёстренького',
#  ',',
#  'многие',
#  'коротышки',
#  'тоже',
#  'совершили',
#  'поездку',
#  'в',
#  'Солнечный',
#  'город',
#  ',',
#  'а',
#  'когда',
#  'возвратились',
#  ',',
#  'решили',
#  'и',
# ...

# %%
nltk.download('stopwords')
stop = stopwords.words('russian')
stop
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Ustin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
# ...

# %%
token_fil3 = [token for token in words if token not in stop]
token_fil3
# Out:
# ['Николай',
#  'Носов',
#  'НЕЗНАЙКА',
#  'НА',
#  'ЛУНЕ',
#  'РОМАН-СКАЗКА',
#  'Иллюстрации',
#  'Генриха',
#  'Валька',
#  'ЧАСТЬ',
#  'I',
#  'Глава',
#  'первая',
#  'КАК',
#  'ЗНАЙКА',
#  'ПОБЕДИЛ',
#  'ПРОФЕССОРА',
#  'ЗВЁЗДОЧКИНА',
#  'С',
#  'тех',
#  'пор',
#  'Незнайка',
#  'совершил',
#  'путешествие',
#  'Солнечный',
#  'город',
#  ',',
#  'прошло',
#  'половиной',
#  'года',
#  '.',
#  'Хотя',
#  'вами',
#  'это',
#  ',',
#  'маленьких',
#  'коротышек',
#  'половиной',
#  'года',
#  '—',
#  'срок',
#  'очень',
#  'большой',
#  '.',
#  'Наслушавшись',
#  'рассказов',
#  'Незнайки',
#  ',',
#  'Кнопочки',
#  'Пачкули',
#  'Пёстренького',
#  ',',
#  'многие',
#  'коротышки',
#  'совершили',
#  'поездку',
#  'Солнечный',
#  'город',
#  ',',
#  'возвратились',
#  ',',
#  'решили',
#  'сделать',
#  'кое-какие',
#  'усовершенствования',
#  '.',
#  'Цветочный',
#  'город',
#  'изменился',
#  'тех',
#  'пор',
#  ',',
#  'узнать',
#  '.',
#  'В',
#  'нём',
#  'появилось',
# ...

# %%
m3 = SnowballStemmer(language='russian')
tokinized = nltk.word_tokenize(text3)
st3 = [m.stem(token_fil) for token_fil in tokinized]
st3
# Out:
# ['никола',
#  'нос',
#  'незнайк',
#  'на',
#  'лун',
#  'роман-сказк',
#  'иллюстрац',
#  'генрих',
#  'вальк',
#  'част',
#  'I',
#  'глав',
#  'перв',
#  'как',
#  'знайк',
#  'побед',
#  'профессор',
#  'звездочкин',
#  'с',
#  'тех',
#  'пор',
#  'как',
#  'незнайк',
#  'соверш',
#  'путешеств',
#  'в',
#  'солнечн',
#  'город',
#  ',',
#  'прошл',
#  'два',
#  'с',
#  'половин',
#  'год',
#  '.',
#  'хот',
#  'для',
#  'нас',
#  'с',
#  'вам',
#  'эт',
#  'не',
#  'так',
#  'уж',
#  'мног',
#  ',',
#  'но',
#  'для',
#  'маленьк',
#  'коротышек',
#  'два',
#  'с',
#  'половин',
#  'год',
#  '—',
#  'срок',
#  'очен',
#  'больш',
#  '.',
#  'наслуша',
#  'рассказ',
#  'незнайк',
#  ',',
#  'кнопочк',
#  'и',
#  'пачкул',
#  'пестреньк',
#  ',',
#  'мног',
#  'коротышк',
#  'тож',
#  'соверш',
#  'поездк',
#  'в',
#  'солнечн',
#  'город',
#  ',',
#  'а',
#  'когд',
#  'возврат',
#  ',',
#  'реш',
#  'и',
#  'у',
#  'себ',
#  'сдела',
#  'кое-как',
#  'усовершенствован',
#  '.',
# ...

# %%
import math
from collections import Counter

# Создание вектора слов для текста
def create_word_vector(text):
    word_counts = Counter(text)
    vector = []
    for word in text:
        vector.append(word_counts[word])
    return vector

# Расчет косинусного сходства
def cosine_similarity(vector1, vector2):
    dot_product = sum(a * b for a, b in zip(vector1, vector2))
    magnitude1 = math.sqrt(sum(a ** 2 for a in vector1))
    magnitude2 = math.sqrt(sum(b ** 2 for b in vector2))
    return dot_product / (magnitude1 * magnitude2)

# Предобработка текстов
text = st
text3 = st3

# Создание векторов слов для текстов
vector1 = create_word_vector(text)
vector2 = create_word_vector(text3)

# Расчет косинусного сходства
similarity = cosine_similarity(vector1, vector2)

# Вывод результата
print("Косинусное сходство:", similarity)
# Out:
# Косинусное сходство: 0.04777803697885257

# %%
with open("64466206.txt") as file:
    text4 = file.read()

# %%
words = word_tokenize(text4)
words
# Out:
# ['Веселая',
#  'семейка',
#  'Николай',
#  'Николаевич',
#  'Носов',
#  'Носов',
#  'нашего',
#  'детства',
#  '«',
#  'Весёлая',
#  'семейка',
#  '»',
#  '–',
#  'увлекательная',
#  'повесть',
#  'известного',
#  'детского',
#  'писателя',
#  'Николая',
#  'Николаевича',
#  'Носова',
#  'о',
#  'двух',
#  'приятелях',
#  ',',
#  'выдумщиках',
#  'и',
#  'фантазёрах',
#  ',',
#  'которые',
#  'не',
#  'привыкли',
#  'скучать',
#  'и',
#  'сидеть',
#  'без',
#  'дела',
#  '.',
#  'И',
#  'вот',
#  'как-то',
#  'раз',
#  'ребятам',
#  'в',
#  'руки',
#  'попала',
#  'книжка',
#  'о',
#  'разведении',
#  'цыплят',
#  '.',
#  'Мальчишки',
#  'недолго',
#  'думая',
#  'приступили',
#  'к',
#  'делу…',
#  'Николай',
#  'Николаевич',
#  'Носов',
#  'Весёлая',
#  'семейка',
#  '©',
#  'Носов',
#  '.',
#  'Текст',
#  ',',
#  'художественные',
#  'образы',
#  ',',
#  'иллюстрации',
#  ',',
#  '2017',
#  '©',
#  'Оформление',
#  '.',
#  'ООО',
#  '«',
#  'Издательская',
#  'Группа',
#  '«',
# ...

# %%
nltk.download('stopwords')
stop = stopwords.words('russian')
stop
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Ustin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
# ...

# %%
token_fil4 = [token for token in words if token not in stop]
token_fil4
# Out:
# ['Веселая',
#  'семейка',
#  'Николай',
#  'Николаевич',
#  'Носов',
#  'Носов',
#  'нашего',
#  'детства',
#  '«',
#  'Весёлая',
#  'семейка',
#  '»',
#  '–',
#  'увлекательная',
#  'повесть',
#  'известного',
#  'детского',
#  'писателя',
#  'Николая',
#  'Николаевича',
#  'Носова',
#  'двух',
#  'приятелях',
#  ',',
#  'выдумщиках',
#  'фантазёрах',
#  ',',
#  'которые',
#  'привыкли',
#  'скучать',
#  'сидеть',
#  'дела',
#  '.',
#  'И',
#  'как-то',
#  'ребятам',
#  'руки',
#  'попала',
#  'книжка',
#  'разведении',
#  'цыплят',
#  '.',
#  'Мальчишки',
#  'недолго',
#  'думая',
#  'приступили',
#  'делу…',
#  'Николай',
#  'Николаевич',
#  'Носов',
#  'Весёлая',
#  'семейка',
#  '©',
#  'Носов',
#  '.',
#  'Текст',
#  ',',
#  'художественные',
#  'образы',
#  ',',
#  'иллюстрации',
#  ',',
#  '2017',
#  '©',
#  'Оформление',
#  '.',
#  'ООО',
#  '«',
#  'Издательская',
#  'Группа',
#  '«',
#  'Азбука-Аттикус',
#  '»',
#  ',',
#  '2017',
#  'Machaon®',
#  'Важное',
#  'решение',
# ...

# %%
m4 = SnowballStemmer(language='russian')
tokinized = nltk.word_tokenize(text4)
st4 = [m.stem(token_fil) for token_fil in tokinized]
st4
# Out:
# ['весел',
#  'семейк',
#  'никола',
#  'николаевич',
#  'нос',
#  'нос',
#  'наш',
#  'детств',
#  '«',
#  'весел',
#  'семейк',
#  '»',
#  '–',
#  'увлекательн',
#  'повест',
#  'известн',
#  'детск',
#  'писател',
#  'никол',
#  'николаевич',
#  'носов',
#  'о',
#  'двух',
#  'приятел',
#  ',',
#  'выдумщик',
#  'и',
#  'фантазер',
#  ',',
#  'котор',
#  'не',
#  'привыкл',
#  'скуча',
#  'и',
#  'сидет',
#  'без',
#  'дел',
#  '.',
#  'и',
#  'вот',
#  'как-т',
#  'раз',
#  'ребят',
#  'в',
#  'рук',
#  'попа',
#  'книжк',
#  'о',
#  'разведен',
#  'цыпл',
#  '.',
#  'мальчишк',
#  'недолг',
#  'дум',
#  'приступ',
#  'к',
#  'делу…',
#  'никола',
#  'николаевич',
#  'нос',
#  'весел',
#  'семейк',
#  '©',
#  'нос',
#  '.',
#  'текст',
#  ',',
#  'художествен',
#  'образ',
#  ',',
#  'иллюстрац',
#  ',',
#  '2017',
#  '©',
#  'оформлен',
#  '.',
#  'оо',
#  '«',
#  'издательск',
#  'групп',
#  '«',
#  'азбука-аттикус',
#  '»',
#  ',',
#  '2017',
#  'Machaon®',
#  'важн',
# ...

# %%
import math
from collections import Counter

# Создание вектора слов для текста
def create_word_vector(text):
    word_counts = Counter(text)
    vector = []
    for word in text:
        vector.append(word_counts[word])
    return vector

# Расчет косинусного сходства
def cosine_similarity(vector1, vector2):
    dot_product = sum(a * b for a, b in zip(vector1, vector2))
    magnitude1 = math.sqrt(sum(a ** 2 for a in vector1))
    magnitude2 = math.sqrt(sum(b ** 2 for b in vector2))
    return dot_product / (magnitude1 * magnitude2)

# Предобработка текстов
text = st
text4 = st4

# Создание векторов слов для текстов
vector1 = create_word_vector(text)
vector2 = create_word_vector(text4)

# Расчет косинусного сходства
similarity = cosine_similarity(vector1, vector2)

# Вывод результата
print("Косинусное сходство:", similarity)
# Out:
# Косинусное сходство: 0.2617932304193257

# %%
with open("Nosov Nikolay. Dnevnik Koli Sinicina - BooksCafe.Net.txt") as file:
    text5 = file.read()

# %%
words = word_tokenize(text5)
words
# Out:
# ['Николай',
#  'Носов',
#  'Дневник',
#  'Коли',
#  'Синицына',
#  '28',
#  'мая',
#  'У',
#  'меня',
#  'сегодня',
#  'очень',
#  'радостный',
#  'день',
#  ':',
#  'занятия',
#  'в',
#  'школе',
#  'окончились',
#  'и',
#  'я',
#  'перешел',
#  'в',
#  'следующий',
#  'класс',
#  'с',
#  'одними',
#  'пятерками',
#  '.',
#  'Завтра',
#  'начинаются',
#  'каникулы',
#  '.',
#  'Я',
#  'задумал',
#  'во',
#  'время',
#  'каникул',
#  'вести',
#  'дневник',
#  '.',
#  'Мама',
#  'сказала',
#  ',',
#  'что',
#  'подарит',
#  'мне',
#  'вечную',
#  'ручку',
#  ',',
#  'если',
#  'я',
#  'буду',
#  'вести',
#  'дневник',
#  'аккуратно',
#  '.',
#  'Я',
#  'купил',
#  'толстую',
#  'общую',
#  'тетрадь',
#  'в',
#  'синей',
#  'обложке',
#  'и',
#  'решил',
#  'аккуратно',
#  'записывать',
#  'в',
#  'эту',
#  'тетрадь',
#  'разные',
#  'интересные',
#  'случаи',
#  '.',
#  'Как',
#  'только',
#  'случится',
#  'что-нибудь',
#  'интересное',
#  ',',
#  'я',
#  'сейчас',
#  'же',
# ...

# %%
nltk.download('stopwords')
stop = stopwords.words('russian')
stop
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Ustin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
# ...

# %%
token_fil5 = [token for token in words if token not in stop]
token_fil5
# Out:
# ['Николай',
#  'Носов',
#  'Дневник',
#  'Коли',
#  'Синицына',
#  '28',
#  'мая',
#  'У',
#  'сегодня',
#  'очень',
#  'радостный',
#  'день',
#  ':',
#  'занятия',
#  'школе',
#  'окончились',
#  'перешел',
#  'следующий',
#  'класс',
#  'одними',
#  'пятерками',
#  '.',
#  'Завтра',
#  'начинаются',
#  'каникулы',
#  '.',
#  'Я',
#  'задумал',
#  'время',
#  'каникул',
#  'вести',
#  'дневник',
#  '.',
#  'Мама',
#  'сказала',
#  ',',
#  'подарит',
#  'вечную',
#  'ручку',
#  ',',
#  'буду',
#  'вести',
#  'дневник',
#  'аккуратно',
#  '.',
#  'Я',
#  'купил',
#  'толстую',
#  'общую',
#  'тетрадь',
#  'синей',
#  'обложке',
#  'решил',
#  'аккуратно',
#  'записывать',
#  'тетрадь',
#  'разные',
#  'интересные',
#  'случаи',
#  '.',
#  'Как',
#  'случится',
#  'что-нибудь',
#  'интересное',
#  ',',
#  'запишу',
#  '.',
#  'Кроме',
#  ',',
#  'буду',
#  'записывать',
#  'свои',
#  'мысли',
#  '.',
#  'Буду',
#  'думать',
#  'разных',
#  'вещах',
#  ',',
#  'голову',
#  'придет',
# ...

# %%
m5 = SnowballStemmer(language='russian')
tokinized = nltk.word_tokenize(text5)
st5 = [m.stem(token_fil) for token_fil in tokinized]
st5
# Out:
# ['никола',
#  'нос',
#  'дневник',
#  'кол',
#  'синицын',
#  '28',
#  'ма',
#  'у',
#  'мен',
#  'сегодн',
#  'очен',
#  'радостн',
#  'ден',
#  ':',
#  'занят',
#  'в',
#  'школ',
#  'оконч',
#  'и',
#  'я',
#  'перешел',
#  'в',
#  'след',
#  'класс',
#  'с',
#  'одн',
#  'пятерк',
#  '.',
#  'завтр',
#  'начина',
#  'каникул',
#  '.',
#  'я',
#  'задума',
#  'во',
#  'врем',
#  'каникул',
#  'вест',
#  'дневник',
#  '.',
#  'мам',
#  'сказа',
#  ',',
#  'что',
#  'подар',
#  'мне',
#  'вечн',
#  'ручк',
#  ',',
#  'есл',
#  'я',
#  'буд',
#  'вест',
#  'дневник',
#  'аккуратн',
#  '.',
#  'я',
#  'куп',
#  'толст',
#  'общ',
#  'тетрад',
#  'в',
#  'син',
#  'обложк',
#  'и',
#  'реш',
#  'аккуратн',
#  'записыва',
#  'в',
#  'эт',
#  'тетрад',
#  'разн',
#  'интересн',
#  'случа',
#  '.',
#  'как',
#  'тольк',
#  'случ',
#  'что-нибуд',
#  'интересн',
#  ',',
#  'я',
#  'сейчас',
#  'же',
#  'запиш',
#  '.',
#  'кром',
#  'тог',
#  ',',
#  'буд',
#  'записыва',
#  'сво',
# ...

# %%
import math
from collections import Counter

# Создание вектора слов для текста
def create_word_vector(text):
    word_counts = Counter(text)
    vector = []
    for word in text:
        vector.append(word_counts[word])
    return vector

# Расчет косинусного сходства
def cosine_similarity(vector1, vector2):
    dot_product = sum(a * b for a, b in zip(vector1, vector2))
    magnitude1 = math.sqrt(sum(a ** 2 for a in vector1))
    magnitude2 = math.sqrt(sum(b ** 2 for b in vector2))
    return dot_product / (magnitude1 * magnitude2)

# Предобработка текстов
text = st
text3 = st5

# Создание векторов слов для текстов
vector1 = create_word_vector(text)
vector2 = create_word_vector(text5)

# Расчет косинусного сходства
similarity = cosine_similarity(vector1, vector2)

# Вывод результата
print("Косинусное сходство:", similarity)
# Out:
# Косинусное сходство: 0.08196205523707326

# %%
with open("Vitya_Maleev_v_shkole_i_doma.txt") as file:
    text6 = file.read()

# %%
words = word_tokenize(text6)
words
# Out:
# ['Николай',
#  'Носов',
#  '.',
#  'Витя',
#  'Малеев',
#  'в',
#  'школе',
#  'и',
#  'дома',
#  '.',
#  'ГЛАВА',
#  'ПЕРВАЯ',
#  'Подумать',
#  'только',
#  ',',
#  'как',
#  'быстро',
#  'время',
#  'летит',
#  '!',
#  'Не',
#  'успел',
#  'я',
#  'оглянуться',
#  ',',
#  'как',
#  'каникулы',
#  'кончились',
#  'и',
#  'пришла',
#  'пора',
#  'идти',
#  'в',
#  'школу',
#  '.',
#  'Целое',
#  'лето',
#  'я',
#  'только',
#  'и',
#  'делал',
#  ',',
#  'что',
#  'бегал',
#  'по',
#  'улицам',
#  'да',
#  'играл',
#  'в',
#  'футбол',
#  ',',
#  'а',
#  'о',
#  'книжках',
#  'даже',
#  'позабыл',
#  'думать',
#  '.',
#  'То',
#  'есть',
#  'я',
#  'читал',
#  'иногда',
#  'книжки',
#  ',',
#  'только',
#  'не',
#  'учебные',
#  ',',
#  'а',
#  'какие-нибудь',
#  'сказки',
#  'или',
#  'рассказы',
#  ',',
#  'а',
#  'так',
#  'чтоб',
#  'позаниматься',
#  'по',
#  'русскому',
#  'языку',
#  'или',
#  'по',
#  'арифметике',
#  '-',
#  'этого',
#  'не',
#  'было',
#  'По',
# ...

# %%
nltk.download('stopwords')
stop = stopwords.words('russian')
stop
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Ustin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
# ...

# %%
token_fil6 = [token for token in words if token not in stop]
token_fil6
# Out:
# ['Николай',
#  'Носов',
#  '.',
#  'Витя',
#  'Малеев',
#  'школе',
#  'дома',
#  '.',
#  'ГЛАВА',
#  'ПЕРВАЯ',
#  'Подумать',
#  ',',
#  'быстро',
#  'время',
#  'летит',
#  '!',
#  'Не',
#  'успел',
#  'оглянуться',
#  ',',
#  'каникулы',
#  'кончились',
#  'пришла',
#  'пора',
#  'идти',
#  'школу',
#  '.',
#  'Целое',
#  'лето',
#  'делал',
#  ',',
#  'бегал',
#  'улицам',
#  'играл',
#  'футбол',
#  ',',
#  'книжках',
#  'позабыл',
#  'думать',
#  '.',
#  'То',
#  'читал',
#  'книжки',
#  ',',
#  'учебные',
#  ',',
#  'какие-нибудь',
#  'сказки',
#  'рассказы',
#  ',',
#  'позаниматься',
#  'русскому',
#  'языку',
#  'арифметике',
#  '-',
#  'По',
#  'русскому',
#  'учился',
#  ',',
#  'арифметики',
#  'любил',
#  '.',
#  'Хуже',
#  '-',
#  'это',
#  'задачи',
#  'решать',
#  '.',
#  'Ольга',
#  'Николаевна',
#  'хотела',
#  'дать',
#  'работу',
#  'лето',
#  'арифметике',
#  ',',
#  'пожалела',
#  'перевела',
#  'четвертый',
#  'класс',
#  ',',
#  'работы',
#  '.',
#  '-',
# ...

# %%
m6 = SnowballStemmer(language='russian')
tokinized = nltk.word_tokenize(text6)
st6 = [m.stem(token_fil) for token_fil in tokinized]
st6
# Out:
# ['никола',
#  'нос',
#  '.',
#  'вит',
#  'мале',
#  'в',
#  'школ',
#  'и',
#  'дом',
#  '.',
#  'глав',
#  'перв',
#  'подума',
#  'тольк',
#  ',',
#  'как',
#  'быстр',
#  'врем',
#  'лет',
#  '!',
#  'не',
#  'успел',
#  'я',
#  'оглянут',
#  ',',
#  'как',
#  'каникул',
#  'конч',
#  'и',
#  'пришл',
#  'пор',
#  'идт',
#  'в',
#  'школ',
#  '.',
#  'цел',
#  'лет',
#  'я',
#  'тольк',
#  'и',
#  'дела',
#  ',',
#  'что',
#  'бега',
#  'по',
#  'улиц',
#  'да',
#  'игра',
#  'в',
#  'футбол',
#  ',',
#  'а',
#  'о',
#  'книжк',
#  'даж',
#  'позаб',
#  'дума',
#  '.',
#  'то',
#  'ест',
#  'я',
#  'чита',
#  'иногд',
#  'книжк',
#  ',',
#  'тольк',
#  'не',
#  'учебн',
#  ',',
#  'а',
#  'какие-нибуд',
#  'сказк',
#  'ил',
#  'рассказ',
#  ',',
#  'а',
#  'так',
#  'чтоб',
#  'позанима',
#  'по',
#  'русск',
#  'язык',
#  'ил',
#  'по',
#  'арифметик',
#  '-',
#  'эт',
#  'не',
#  'был',
#  'по',
#  'русск',
#  'я',
#  'и',
#  'так',
#  'хорош',
#  'уч',
#  ',',
#  'а',
# ...

# %%
import math
from collections import Counter

# Создание вектора слов для текста
def create_word_vector(text):
    word_counts = Counter(text)
    vector = []
    for word in text:
        vector.append(word_counts[word])
    return vector

# Расчет косинусного сходства
def cosine_similarity(vector1, vector2):
    dot_product = sum(a * b for a, b in zip(vector1, vector2))
    magnitude1 = math.sqrt(sum(a ** 2 for a in vector1))
    magnitude2 = math.sqrt(sum(b ** 2 for b in vector2))
    return dot_product / (magnitude1 * magnitude2)

# Предобработка текстов
text = st
text6 = st6

# Создание векторов слов для текстов
vector1 = create_word_vector(text)
vector2 = create_word_vector(text6)

# Расчет косинусного сходства
similarity = cosine_similarity(vector1, vector2)

# Вывод результата
print("Косинусное сходство:", similarity)
# Out:
# Косинусное сходство: 0.08398880477308532
