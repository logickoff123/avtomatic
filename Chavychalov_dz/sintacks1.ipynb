# %%
import spacy
from spacy import displacy
# %pip install natasha
# Out:
# Requirement already satisfied: natasha in c:\users\ustin\appdata\local\programs\python\python310\lib\site-packages (1.6.0)
# Requirement already satisfied: pymorphy2 in c:\users\ustin\appdata\local\programs\python\python310\lib\site-packages (from natasha) (0.9.1)
# Requirement already satisfied: razdel>=0.5.0 in c:\users\ustin\appdata\local\programs\python\python310\lib\site-packages (from natasha) (0.5.0)
# Requirement already satisfied: navec>=0.9.0 in c:\users\ustin\appdata\local\programs\python\python310\lib\site-packages (from natasha) (0.10.0)
# Requirement already satisfied: slovnet>=0.6.0 in c:\users\ustin\appdata\local\programs\python\python310\lib\site-packages (from natasha) (0.6.0)
# Requirement already satisfied: yargy>=0.16.0 in c:\users\ustin\appdata\local\programs\python\python310\lib\site-packages (from natasha) (0.16.0)
# Requirement already satisfied: ipymarkup>=0.8.0 in c:\users\ustin\appdata\local\programs\python\python310\lib\site-packages (from natasha) (0.9.0)
# Requirement already satisfied: intervaltree>=3 in c:\users\ustin\appdata\local\programs\python\python310\lib\site-packages (from ipymarkup>=0.8.0->natasha) (3.1.0)
# Requirement already satisfied: numpy in c:\users\ustin\appdata\local\programs\python\python310\lib\site-packages (from navec>=0.9.0->natasha) (1.26.1)
# Requirement already satisfied: dawg-python>=0.7.1 in c:\users\ustin\appdata\local\programs\python\python310\lib\site-packages (from pymorphy2->natasha) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in c:\users\ustin\appdata\local\programs\python\python310\lib\site-packages (from pymorphy2->natasha) (2.4.417127.4579844)
# Requirement already satisfied: docopt>=0.6 in c:\users\ustin\appdata\local\programs\python\python310\lib\site-packages (from pymorphy2->natasha) (0.6.2)
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in c:\users\ustin\appdata\local\programs\python\python310\lib\site-packages (from intervaltree>=3->ipymarkup>=0.8.0->natasha) (2.4.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
nlp = spacy.load('ru_core_news_sm')

# %%
with open("57373677.txt") as file:
    text = file.read()

# %%
doc = nlp(text)

# %%
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Живая ADJ amod
# шляпа NOUN nsubj
#
#  SPACE dep
# Николай PROPN appos
# Николаевич PROPN flat:name
# Носов PROPN flat:name
#
#
#
#  SPACE dep
# Классика PROPN flat:name
# нашего DET det
# детства NOUN nmod
#
#  SPACE dep
# Рассказы PROPN nmod
# , PUNCT punct
# как SCONJ case
# и PART advmod
# все DET det
# произведения NOUN appos
# Николая PROPN nmod
# Носова PROPN flat:name
# , PUNCT punct
# давно ADV advmod
# стали VERB ROOT
# не PART cc
# только PART fixed
# классикой NOUN xcomp
# , PUNCT punct
# но CCONJ cc
# и CCONJ fixed
# , PUNCT punct
# без ADP case
# преувеличения NOUN conj
# , PUNCT punct
# национальным ADJ amod
# достоянием NOUN conj
# . PUNCT punct
# В ADP case
# нашей DET det
# стране NOUN obl
# нет VERB ROOT
# ни PART advmod
# одного NUM nummod
# человека NOUN nsubj
# , PUNCT punct
# который PRON nsubj
# бы AUX aux
# не PART advmod
# читал VERB acl:relcl
# в ADP case
# детстве NOUN obl
# про ADP case
# живую ADJ amod
# шляпу NOUN obl
# и CCONJ cc
# Мишкину PROPN conj
# кашу NOUN flat:name
# , PUNCT punct
# про ADP case
# фантазёров NOUN conj
# или CCONJ cc
# Бобика PROPN conj
# в ADP case
# гостях NOUN nmod
# у ADP case
# Барбоса PROPN obl
# … PUNCT punct
#
#
#  SPACE dep
# Герои NOUN nsubj
# рассказов NOUN nmod
# Носова PROPN nmod
# – PUNCT punct
# такие DET det
# же PART advmod
# живые ADJ ROOT
# и CCONJ cc
# настоящие ADJ conj
# , PUNCT punct
# как SCONJ case
# и PART advmod
# любой DET det
# соседский ADJ amod
# мальчишка NOUN conj
# или CCONJ cc
# девчонка NOUN conj
# . PUNCT punct
# Они PRON nsubj
# так ADV advmod
# же PART advmod
# учатся VERB ROOT
# в ADP case
# школе NOUN obl
# , PUNCT punct
# играют VERB conj
# и CCONJ cc
# проказничают VERB conj
# , PUNCT punct
# так ADV advmod
# же PART advmod
# радуются VERB conj
# и CCONJ cc
# грустят VERB conj
# , PUNCT punct
# ссорятся VERB conj
# и CCONJ cc
# мирятся VERB conj
# . PUNCT punct
#
#
#  SPACE dep
# С ADP case
# детства NOUN obl
# любимые ADJ amod
# рассказы NOUN nsubj:pass
# Николая PROPN nmod
# Носова PROPN flat:name
# прекрасно ADV advmod
# проиллюстрированы VERB ROOT
# замечательными ADJ amod
# рисунками NOUN obl:agent
# Германа PROPN nmod
# Огородникова PROPN flat:name
# . PUNCT punct
#
#
#
#
#
#
#  SPACE dep
# Николай PROPN nsubj
# Николаевич PROPN appos
# Носов PROPN flat:name
#
#
#  SPACE dep
# Живая ADJ amod
# шляпа NOUN appos
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  SPACE dep
# Затейники NOUN appos
#
#
#
#
#
#
#  SPACE dep
# Мы PRON appos
# с ADP case
#   SPACE dep
# Валей PROPN nmod
# затейники NOUN ROOT
# . PUNCT punct
# Мы PRON nsubj
# всегда ADV advmod
# затеваем VERB ROOT
# какие DET det
# - DET det
# нибудь DET det
# игры NOUN obj
# . PUNCT punct
#
#
#  SPACE dep
# Один NUM nummod
# раз NOUN obl
# мы PRON nsubj
# читали VERB ROOT
# сказку NOUN obj
# « PUNCT punct
# Три NUM nummod:gov
# поросёнка NOUN appos
# » PUNCT punct
# . PUNCT punct
# А CCONJ cc
# потом ADV advmod
# стали VERB ROOT
# играть VERB xcomp
# . PUNCT punct
# Сначала ADV advmod
# мы PRON nsubj
# бегали VERB ROOT
# по ADP case
# комнате NOUN obl
# , PUNCT punct
# прыгали VERB conj
# и CCONJ cc
# кричали VERB conj
# : PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Нам PRON iobj
# не PART advmod
# страшен VERB parataxis
# серый ADJ amod
# волк NOUN nsubj
# ! PUNCT punct
#
#
#  SPACE dep
# Потом ADV advmod
# мама NOUN nsubj
# ушла VERB ROOT
# в ADP case
# магазин NOUN obl
# , PUNCT punct
# а CCONJ cc
#   SPACE dep
# Валя PROPN nsubj
# сказала VERB conj
# : PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Давай PROPN parataxis
# , PUNCT punct
# Петя PROPN conj
# , PUNCT punct
# сделаем VERB conj
# себе PRON iobj
# домик NOUN obj
# , PUNCT punct
# как SCONJ mark
# у ADP case
# тех DET det
# поросят VERB advcl
# , PUNCT punct
# что SCONJ mark
# в ADP case
# сказке NOUN ccomp
# . PUNCT punct
#
#
#  SPACE dep
# Мы PRON nsubj
# стащили VERB ROOT
# с ADP case
# кровати NOUN obl
# одеяло NOUN obj
# и CCONJ cc
# завесили VERB conj
# им PRON iobj
# стол NOUN obj
# . PUNCT punct
# Вот PART advmod
# и PART advmod
# получился VERB ROOT
# дом NOUN nsubj
# . PUNCT punct
# Мы PRON nsubj
# залезли VERB ROOT
# в ADP case
# него PRON obl
# , PUNCT punct
# а CCONJ cc
# там ADV advmod
# темно ADJ nsubj
# - ADJ ccomp
# темно ADJ conj
# ! PUNCT punct
#
#
#  SPACE dep
# Валя PROPN nsubj
# говорит VERB ROOT
# : PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Вот PART parataxis
# и CCONJ cc
# хорошо ADJ conj
# , PUNCT punct
# что SCONJ mark
# у ADP case
# нас PRON advcl
# свой DET det
# дом NOUN nsubj
# ! PUNCT punct
# Мы PRON nsubj
# всегда ADV advmod
# будем AUX aux
# здесь ADV advmod
# жить VERB ROOT
# и CCONJ cc
# никого PRON obj
# к ADP case
# себе PRON obl
# не PART advmod
# пустим VERB conj
# , PUNCT punct
# а CCONJ cc
# если SCONJ mark
# серый ADJ amod
# волк NOUN nsubj
# придёт VERB advcl
# , PUNCT punct
# мы PRON nsubj
# его PRON obj
# прогоним VERB conj
# . PUNCT punct
#
#
#  SPACE dep
# Я PRON nsubj
# говорю VERB ROOT
# : PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Жалко ADV parataxis
# , PUNCT punct
# что SCONJ mark
# у ADP case
# нас PRON obl
# в ADP case
# домике NOUN obl
# нет VERB ccomp
# окон NOUN nsubj
# , PUNCT punct
# очень ADV advmod
# темно ADJ conj
# ! PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Ничего PRON parataxis
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# говорит VERB parataxis
# Валя PROPN nsubj
# . PUNCT punct
#   SPACE dep
# – PUNCT punct
# У ADP case
# поросят VERB obj
# ведь PART advmod
# домики NOUN nsubj
# бывают VERB conj
# без ADP case
# окон NOUN obl
# . PUNCT punct
#
#
#  SPACE dep
# Я PRON nsubj
# спрашиваю VERB ROOT
# : PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# А CCONJ cc
# ты PRON nsubj
# меня PRON obj
# видишь VERB parataxis
# ? PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Нет PART parataxis
# . PUNCT punct
# А CCONJ cc
# ты PRON nsubj
# меня PRON ROOT
# ? PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# И CCONJ cc
# я PRON nsubj
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# говорю VERB ROOT
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# нет PART conj
# . PUNCT punct
# Я PRON nsubj
# даже PART advmod
# себя PRON obj
# не PART advmod
# вижу VERB ROOT
# . PUNCT punct
#
#
#  SPACE dep
# Вдруг ADV advmod
# меня PRON obj
# кто PRON nsubj
# - PRON nsubj
# то PRON nsubj
# как SCONJ advmod
# схватит VERB ROOT
# за ADP case
# ногу NOUN obl
# ! PUNCT punct
# Я PRON nsubj
# как SCONJ mark
# закричу VERB ROOT
# ! PUNCT punct
# Выскочил VERB ROOT
# из ADP case
# - ADP case
# под ADP case
# стола NOUN obl
# , PUNCT punct
# а CCONJ cc
#   SPACE dep
# Валя PROPN conj
# за ADP case
# мной PRON obl
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Чего PRON nsubj
# ты PRON nsubj
# ? PUNCT punct
#   SPACE dep
# – PUNCT punct
# спрашивает VERB ROOT
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Меня PRON obj
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# говорю VERB parataxis
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# кто PRON nsubj
# - PRON nsubj
# то PRON nsubj
# схватил VERB conj
# за ADP case
# ногу NOUN obl
# . PUNCT punct
# Может VERB parataxis
# быть VERB xcomp
# , PUNCT punct
# серый ADJ amod
# волк NOUN ROOT
# ? PUNCT punct
#
#
#  SPACE dep
# Валя PROPN nsubj
# испугалась VERB ROOT
# и CCONJ cc
# бегом NOUN obl
# из ADP case
# комнаты NOUN nmod
# . PUNCT punct
# Я PRON nsubj
# – PUNCT punct
# за ADP case
# ней PRON ROOT
# . PUNCT punct
# Выбежали VERB ROOT
# в ADP case
# коридор NOUN obl
# и CCONJ cc
# дверь NOUN conj
# захлопнули VERB conj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Давай VERB ROOT
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# говорю VERB conj
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# дверь NOUN conj
# держать VERB nmod
# , PUNCT punct
# чтобы SCONJ mark
# он PRON nsubj
# не PART advmod
# открыл VERB ccomp
# . PUNCT punct
#
#
#
#
#
#
#
#
#
#  SPACE dep
# Держали VERB ROOT
# мы PRON nsubj
# дверь NOUN obj
# , PUNCT punct
# держали VERB conj
# . PUNCT punct
#
#
#  SPACE dep
# Валя PROPN nsubj
# и CCONJ cc
# говорит VERB ROOT
# : PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Может VERB parataxis
# быть VERB xcomp
# , PUNCT punct
# там ADV advmod
# никого PRON nsubj
# нет VERB parataxis
# ? PUNCT punct
#
#
#  SPACE dep
# Я PRON nsubj
# говорю VERB ROOT
# : PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# А CCONJ cc
# кто PRON nsubj
# же PART advmod
# тогда ADV advmod
# меня PRON obj
# за ADP case
# ногу NOUN obl
# трогал VERB parataxis
# ? PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Это PART nsubj
# я PRON parataxis
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# говорит VERB conj
# Валя PROPN nsubj
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# я PRON nsubj
# хотела VERB conj
# узнать VERB xcomp
# , PUNCT punct
# где ADV obl
# ты PRON nsubj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Чего PRON obj
# же PART advmod
# ты PRON nsubj
# раньше ADV advmod
# не PART advmod
# сказала VERB conj
# ? PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Я PRON parataxis
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# говорит VERB parataxis
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# испугалась VERB conj
# . PUNCT punct
# Ты PRON nsubj
# меня PRON obj
# испугал VERB ROOT
# . PUNCT punct
#
#
#  SPACE dep
# Открыли VERB ROOT
# мы PRON nsubj
# дверь NOUN obj
# . PUNCT punct
# В ADP case
# комнате NOUN obl
# никого PRON nsubj
# нет VERB ROOT
# . PUNCT punct
# А CCONJ cc
# к ADP case
# столу NOUN obl
# подойти VERB xcomp
# всё PART advmod
# - PART advmod
# таки PART advmod
# боимся VERB ROOT
# : PUNCT punct
# вдруг ADV advmod
# из ADP case
# - ADP case
# под ADP case
# него PRON obl
# серый ADJ amod
# волк NOUN nsubj
# вылезет VERB parataxis
# ! PUNCT punct
#
#
#  SPACE dep
# Я PRON nsubj
# говорю VERB ROOT
# : PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Пойди VERB parataxis
# сними VERB xcomp
# одеяло NOUN obj
# . PUNCT punct
#
#
#  SPACE dep
# А CCONJ cc
# Валя PROPN nsubj
# говорит VERB ROOT
# : PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Нет PART parataxis
# , PUNCT punct
# ты PRON nsubj
# пойди VERB parataxis
# ! PUNCT punct
#
#
#  SPACE dep
# Я PRON nsubj
# говорю VERB ROOT
# : PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Там ADV advmod
# же PART advmod
# никого PRON nsubj
# нет VERB parataxis
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# А CCONJ cc
# может VERB parataxis
# быть VERB xcomp
# , PUNCT punct
# есть VERB conj
# ! PUNCT punct
#
#
#  SPACE dep
# Я PRON nsubj
# подкрался VERB ROOT
# на ADP case
# цыпочках NOUN obl
# к ADP case
# столу NOUN obl
# , PUNCT punct
# дёрнул VERB conj
# за ADP case
# край NOUN obl
# одеяла NOUN obj
# и CCONJ cc
# бегом NOUN conj
# к ADP case
# двери NOUN nmod
# . PUNCT punct
# Одеяло NOUN nsubj
# упало VERB ROOT
# , PUNCT punct
# а CCONJ cc
# под ADP case
# столом NOUN obl
# никого PRON nsubj
# нет VERB conj
# . PUNCT punct
# Мы PRON nsubj
# обрадовались VERB ROOT
# . PUNCT punct
# Хотели VERB ROOT
# починить VERB xcomp
# домик NOUN obj
# , PUNCT punct
# только PART advmod
# Валя PROPN nsubj
# говорит VERB conj
# : PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Вдруг ADV advmod
# опять ADV advmod
# кто PRON nsubj
# - PRON nsubj
# нибудь PRON nsubj
# за ADP case
# ногу NOUN obl
# схватит VERB parataxis
# ! PUNCT punct
#
#
#  SPACE dep
# Так ADV advmod
# и PART fixed
# не PART advmod
# стали VERB ROOT
# больше ADV xcomp
# в ADP case
#   SPACE dep
# « PUNCT punct
# три NUM nummod:gov
# поросёнка NOUN obl
# » PUNCT punct
# играть VERB xcomp
# . PUNCT punct
#
#
#
#
#
#
#
#
#
#
#  SPACE dep
# Леденец NOUN nsubj
#
#
#
#  SPACE dep
# Мама NOUN appos
# уходила VERB ROOT
# из ADP case
# дому NOUN obl
# и CCONJ cc
# сказала VERB conj
# Мише PROPN iobj
# : PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Я PRON nsubj
# ухожу VERB parataxis
# , PUNCT punct
# Мишенька PROPN conj
# , PUNCT punct
# а CCONJ cc
# ты PRON nsubj
# веди VERB conj
# себя PRON obj
# хорошо ADV advmod
# . PUNCT punct
# Не PART advmod
# шали VERB ROOT
# без ADP case
# меня PRON obl
# и CCONJ cc
# ничего PRON nsubj
# не PART advmod
# трогай VERB conj
# . PUNCT punct
# За ADP case
# это PRON obl
# подарю VERB ROOT
# тебе PRON iobj
# большой ADJ amod
# красный ADJ amod
# леденец NOUN nsubj
# . PUNCT punct
#
#
#  SPACE dep
# Мама NOUN nsubj
# ушла VERB ROOT
# . PUNCT punct
# Миша PROPN nsubj
# сначала ADV advmod
# вёл VERB ROOT
# себя PRON obj
# хорошо ADV advmod
# : PUNCT punct
# не PART advmod
# шалил VERB parataxis
# и CCONJ cc
# ничего PRON obj
# не PART advmod
# трогал VERB conj
# . PUNCT punct
# Потом ADV advmod
# он PRON nsubj
# только PART advmod
# подставил VERB ROOT
# к ADP case
# буфету NOUN obl
# стул NOUN obj
# , PUNCT punct
# залез VERB conj
# на ADP case
# него PRON obl
# и CCONJ cc
# открыл VERB conj
# у ADP case
# буфета NOUN obl
# дверцы NOUN obj
# . PUNCT punct
# Стоит VERB ROOT
# и CCONJ cc
# смотрит VERB conj
# в ADP case
# буфет NOUN obl
# , PUNCT punct
# а CCONJ cc
# сам ADJ acl
# думает VERB conj
# : PUNCT punct
#
#
#  SPACE dep
# « PUNCT punct
# Я PRON nsubj
# ведь PART advmod
# ничего PRON obj
# не PART advmod
# трогаю VERB parataxis
# , PUNCT punct
# только PART advmod
# смотрю VERB conj
# » PUNCT punct
# . PUNCT punct
#
#
#  SPACE dep
# А CCONJ cc
# в ADP case
# буфете NOUN obl
# стояла VERB ROOT
# сахарница NOUN nsubj
# . PUNCT punct
# Он PRON nsubj
# взял VERB ROOT
# её PRON obj
# и CCONJ cc
# поставил VERB conj
# на ADP case
# стол NOUN obl
# . PUNCT punct
#
#
#  SPACE dep
# « PUNCT punct
# Я PRON nsubj
# только PART advmod
# посмотрю VERB ROOT
# , PUNCT punct
# а CCONJ cc
# ничего PRON obj
# трогать VERB conj
# не PART advmod
# буду AUX aux
# » PUNCT punct
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# думает VERB parataxis
# . PUNCT punct
#
#
#  SPACE dep
# Открыл VERB ROOT
# крышку NOUN obj
# , PUNCT punct
# видит VERB conj
# – PUNCT punct
# там ADV advmod
# что PRON nsubj
# - PRON conj
# то PRON nsubj
# красное VERB parataxis
# сверху ADV advmod
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Э PROPN case
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# говорит VERB ROOT
# Миша PROPN nsubj
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# да CCONJ cc
# это PRON nsubj
# ведь PART advmod
# леденец NOUN conj
# ! PUNCT punct
# Наверно ADV ROOT
# , PUNCT punct
# как ADV advmod
# раз NOUN fixed
# тот DET obl
# самый ADJ amod
# , PUNCT punct
# который PRON obj
# мне PRON iobj
# обещала VERB acl:relcl
# мама NOUN nsubj
# . PUNCT punct
#
#
#  SPACE dep
# Он PRON nsubj
# запустил VERB ROOT
# в ADP case
# сахарницу NOUN obl
# руку NOUN obj
# и CCONJ cc
# вытащил VERB conj
# леденец NOUN obj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Ого PROPN ROOT
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# говорит VERB parataxis
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# большущий VERB conj
# ! PUNCT punct
# И CCONJ cc
# сладкий ADJ ROOT
# , PUNCT punct
# должно ADJ parataxis
# быть VERB xcomp
# . PUNCT punct
#
#
#  SPACE dep
# Миша PROPN nsubj
# лизнул VERB ROOT
# его PRON obj
# и CCONJ cc
# думает VERB conj
# : PUNCT punct
#
#
#  SPACE dep
# « PUNCT punct
# Пососу NOUN iobj
# немножко ADV advmod
# и CCONJ cc
# положу VERB conj
# обратно ADV advmod
# » PUNCT punct
# . PUNCT punct
#
#
#  SPACE dep
# И CCONJ cc
# стал VERB ROOT
# сосать VERB xcomp
# . PUNCT punct
# Пососёт NOUN nsubj
# , PUNCT punct
# пососёт NOUN conj
# и CCONJ cc
# посмотрит VERB conj
# , PUNCT punct
# много ADV advmod
# ли PART advmod
# ещё ADV advmod
# осталось VERB ROOT
# . PUNCT punct
# И CCONJ cc
# всё PART nsubj
# ему PRON iobj
# кажется VERB ROOT
# – PUNCT punct
# много ADV parataxis
# . PUNCT punct
# Наконец ADV advmod
# леденец NOUN nsubj
# стал VERB ROOT
# совсем ADV advmod
# маленький ADJ xcomp
# , PUNCT punct
# со ADP case
# спичку NOUN conj
# . PUNCT punct
# Тогда ADV advmod
# Мишенька PROPN nsubj
# положил VERB ROOT
# его PRON obj
# обратно ADV advmod
# в ADP case
# сахарницу NOUN obl
# . PUNCT punct
# Стоит VERB ROOT
# , PUNCT punct
# пальцы NOUN nsubj
# облизывает VERB conj
# , PUNCT punct
# смотрит VERB conj
# на ADP case
# леденец NOUN obl
# , PUNCT punct
# а CCONJ cc
# сам ADJ acl
# думает VERB conj
# : PUNCT punct
#
#
#  SPACE dep
# « PUNCT punct
# Съем NOUN nsubj
# я PRON nsubj
# его PRON det
# совсем ADV parataxis
# . PUNCT punct
# Всё ADV advmod
# равно ADJ fixed
# мне PRON iobj
# мама NOUN nsubj
# отдаст VERB ROOT
# . PUNCT punct
# Ведь PART advmod
# я PRON nsubj
# хорошо ADV advmod
# себя PRON obj
# веду VERB ROOT
# : PUNCT punct
# не PART advmod
# шалю NOUN parataxis
# и CCONJ cc
# ничего PRON obj
# такого DET obj
# не PART advmod
# делаю VERB conj
# » PUNCT punct
# . PUNCT punct
#
#
#  SPACE dep
# Миша PROPN nsubj
# достал VERB ROOT
# леденец NOUN obj
# , PUNCT punct
# сунул VERB conj
# в ADP case
# рот NOUN obl
# , PUNCT punct
# а CCONJ cc
# сахарницу NOUN nsubj
# хотел VERB conj
# на ADP case
# место NOUN obl
# поставить VERB xcomp
# . PUNCT punct
# Взял VERB ROOT
# её PRON obj
# , PUNCT punct
# а CCONJ cc
# она PRON nsubj
# прилипла VERB conj
# к ADP case
# рукам NOUN obl
# – PUNCT punct
# и CCONJ cc
# бух PROPN conj
# на ADP case
# пол NOUN nmod
# . PUNCT punct
# Разбилась VERB ROOT
# на ADP case
# две NUM nummod:gov
# половинки NOUN obl
# . PUNCT punct
# Сахар NOUN nsubj
# рассыпался VERB ROOT
# . PUNCT punct
#
#
#  SPACE dep
# Мишенька PROPN nsubj
# испугался VERB ROOT
# : PUNCT punct
#
#
#  SPACE dep
# « PUNCT punct
# Что PRON nsubj
# теперь ADV advmod
# мама NOUN nsubj
# скажет VERB parataxis
# ? PUNCT punct
# » PUNCT punct
#
#
#  SPACE dep
# Взял VERB parataxis
# он PRON nsubj
# две NUM nummod:gov
# половинки NOUN obj
# и CCONJ cc
# прислонил VERB conj
# друг PRON obj
# к ADP fixed
# дружке NOUN fixed
# . PUNCT punct
# Они PRON nsubj
# ничего PRON ROOT
# , PUNCT punct
# держатся VERB conj
# . PUNCT punct
# Даже PART advmod
# незаметно ADJ ROOT
# , PUNCT punct
# что SCONJ mark
# сахарница NOUN nsubj:pass
# разбита VERB ccomp
# . PUNCT punct
# Он PRON nsubj
# сложил VERB ROOT
# сахар NOUN obj
# обратно ADV advmod
# , PUNCT punct
# накрыл VERB conj
# крышкой NOUN iobj
# и CCONJ cc
# осторожно ADV advmod
# поставил VERB conj
# в ADP case
# буфет NOUN obl
# . PUNCT punct
#
#
#  SPACE dep
# Наконец ADV advmod
# мама NOUN nsubj
# приходит VERB ROOT
# : PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Ну PART discourse
# , PUNCT punct
# как ADV advmod
# ты PRON nsubj
# себя PRON obj
# вёл VERB parataxis
# ? PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Хорошо ADJ parataxis
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Вот PART advmod
# умница NOUN nsubj
# ! PUNCT punct
# Получай PROPN ROOT
# леденец NOUN nsubj
# . PUNCT punct
#
#
#  SPACE dep
# Мама NOUN nsubj
# открыла VERB ROOT
# буфет NOUN obj
# , PUNCT punct
# взяла VERB conj
# сахарницу NOUN obj
# … PUNCT punct
# Ах INTJ ROOT
# ! PUNCT punct
# .. PUNCT punct
# Сахарница NOUN nsubj
# развалилась VERB ROOT
# , PUNCT punct
# сахар NOUN nsubj
# посыпался VERB conj
# на ADP case
# пол NOUN obl
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Что PRON nsubj
# ж PART advmod
# это PRON nsubj
# такое DET det
# ? PUNCT punct
# Кто PRON nsubj
# сахарницу NOUN obj
# разбил VERB ROOT
# ? PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Это PRON nsubj
# не PART advmod
# я PRON nsubj
# . PUNCT punct
# Это PRON nsubj
# она PRON ROOT
# сама ADJ amod
# … PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Ах PART appos
# , PUNCT punct
# сама ADJ acl
# разбилась VERB conj
# ! PUNCT punct
# Ну PART discourse
# , PUNCT punct
# это PRON nsubj
# понятно ADJ ROOT
# . PUNCT punct
# А CCONJ cc
# леденец NOUN nsubj
# - NOUN nsubj
# то ADV nsubj
# куда ADV advmod
# девался VERB ROOT
# ? PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Леденец PROPN parataxis
# … PUNCT punct
# Леденец NOUN ROOT
# … PUNCT punct
# Я PRON nsubj
# его PRON obj
# съел VERB ROOT
# . PUNCT punct
# Я PRON nsubj
# себя PRON obj
# вёл PROPN nsubj
# хорошо ADV ROOT
# , PUNCT punct
# ну PART discourse
# и CCONJ cc
#   SPACE dep
# съел VERB conj
# его PRON obj
# . PUNCT punct
# Вот PART ROOT
# … PUNCT punct
#
#
#
#
#
#
#
#
#
#
#  SPACE dep
# Карасик PROPN nsubj
#
#
#
#  SPACE dep
# Мама NOUN nsubj
# недавно ADV advmod
# подарила VERB ROOT
# Виталику PROPN iobj
# аквариум NOUN obj
# с ADP case
# рыбкой NOUN nmod
# . PUNCT punct
# Очень ADV advmod
# хорошая ADJ nsubj
# была AUX cop
# рыбка NOUN ROOT
# , PUNCT punct
# красивая ADJ conj
# ! PUNCT punct
# Серебристый ADJ amod
# карасик NOUN ROOT
# – PUNCT punct
# вот PART advmod
# как ADV advmod
# она PRON nsubj
# называлась VERB parataxis
# . PUNCT punct
# Виталик NOUN nsubj
# был AUX cop
# рад ADJ ROOT
# , PUNCT punct
# что SCONJ mark
# у ADP case
# него PRON obl
# есть VERB ccomp
# карасик NOUN nsubj
# . PUNCT punct
# Первое ADJ amod
# время NOUN obl
# он PRON nsubj
# очень ADV advmod
# интересовался VERB ROOT
# рыбкой NOUN obl
# – PUNCT punct
# кормил VERB parataxis
# её PRON obj
# , PUNCT punct
# менял VERB conj
# воду NOUN obj
# в ADP case
# аквариуме NOUN obl
# , PUNCT punct
# а CCONJ cc
# потом ADV advmod
# привык VERB conj
# к ADP case
# ней PRON obl
# и CCONJ cc
# иногда ADV advmod
# даже PART advmod
# забывал VERB conj
# её PRON obj
# вовремя ADV advmod
# покормить VERB xcomp
# . PUNCT punct
#
#
#  SPACE dep
# А CCONJ cc
# ещё ADV advmod
# у ADP case
# Виталика PROPN obl
# был AUX ROOT
# котёнок NOUN nsubj
# Мурзик PROPN appos
# . PUNCT punct
# Он PRON nsubj
# был AUX cop
# серый ADJ ROOT
# , PUNCT punct
# пушистый ADJ conj
# , PUNCT punct
# а CCONJ cc
# глаза NOUN conj
# у ADP case
# него PRON obl
# были VERB conj
# большие ADJ conj
# , PUNCT punct
# зелёные VERB conj
# . PUNCT punct
# Мурзик PROPN nsubj
# очень ADV advmod
# любил VERB ROOT
# смотреть VERB xcomp
# на ADP case
# рыбку NOUN obl
# . PUNCT punct
# По ADP case
# целым ADJ amod
# часам NOUN obl
# он PRON nsubj
# сидел VERB ROOT
# возле ADP case
# аквариума NOUN obl
# и CCONJ cc
# не PART advmod
# сводил VERB conj
# глаз NOUN obj
# с ADP case
# карасика NOUN obl
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Ты PRON nsubj
# смотри VERB obj
# за ADP case
# Мурзиком PROPN obl
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# говорила VERB parataxis
# Виталику NOUN iobj
# мама NOUN nsubj
# . PUNCT punct
#   SPACE dep
# – PUNCT punct
# Как ADV advmod
# бы AUX aux
# он PRON nsubj
# не PART advmod
# съел VERB ROOT
# твоего DET det
# карася NOUN obj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Не PART advmod
# съест VERB ROOT
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# отвечал VERB conj
# Виталик PROPN nsubj
# . PUNCT punct
#   SPACE dep
# – PUNCT punct
# Я PRON nsubj
# буду AUX aux
# смотреть VERB parataxis
# . PUNCT punct
#
#
#  SPACE dep
# Однажды ADV advmod
# , PUNCT punct
# когда SCONJ mark
# мамы NOUN nsubj
# не PART advmod
# было AUX advcl
# дома ADV nsubj
# , PUNCT punct
# к ADP case
#   SPACE dep
# Виталику PROPN obl
# пришёл VERB ROOT
# его PRON nmod
# друг NOUN nsubj
# Серёжа PROPN appos
# . PUNCT punct
# Он PRON nsubj
# увидел VERB ROOT
# в ADP case
# аквариуме NOUN obl
# рыбку NOUN obj
# и CCONJ cc
# сказал VERB conj
# : PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Давай VERB parataxis
# меняться VERB xcomp
# . PUNCT punct
# Ты PRON nsubj
# дай VERB ROOT
# мне PRON iobj
# карасика NOUN obj
# , PUNCT punct
# а CCONJ cc
# я PRON nsubj
# , PUNCT punct
# если SCONJ mark
# хочешь VERB advcl
# , PUNCT punct
# дам VERB conj
# тебе PRON iobj
# свой DET det
# свисток NOUN obj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Зачем ADV advmod
# мне PRON iobj
# свисток NOUN ROOT
# ? PUNCT punct
#   SPACE dep
# – PUNCT punct
# сказал VERB parataxis
# Виталик PROPN nsubj
# . PUNCT punct
#   SPACE dep
# – PUNCT punct
# По ADV parataxis
# - ADV parataxis
# моему ADV parataxis
# , PUNCT punct
# рыбка NOUN nsubj
# лучше ADJ ROOT
# свистка NOUN obl
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Чем PRON obl
# же PART advmod
# она PRON nsubj
# лучше ADJ advmod
# ? PUNCT punct
# Свисток NOUN nsubj
# свистеть VERB xcomp
# может VERB ROOT
# . PUNCT punct
# А CCONJ cc
# рыбка NOUN nsubj
# что PRON ROOT
# ? PUNCT punct
# Разве PART advmod
# может VERB ROOT
# рыбка NOUN nsubj
# свистеть VERB xcomp
# ? PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Зачем ADV advmod
# же PART advmod
# рыбке NOUN obj
# свистеть VERB xcomp
# ? PUNCT punct
#   SPACE dep
# – PUNCT punct
# ответил VERB parataxis
# Виталик PROPN nsubj
# . PUNCT punct
#   SPACE dep
# – PUNCT punct
# Рыбка PROPN nsubj
# свистеть VERB xcomp
# не PART advmod
# может VERB ROOT
# , PUNCT punct
# зато CCONJ cc
# она PRON nsubj
# плавает VERB conj
# . PUNCT punct
# А CCONJ cc
# свисток NOUN nsubj
# разве PART advmod
# может VERB ROOT
# плавать VERB xcomp
# ? PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Сказал VERB parataxis
# ! PUNCT punct
#   SPACE dep
# – PUNCT punct
# засмеялся VERB parataxis
# Серёжа PROPN iobj
# . PUNCT punct
#   SPACE dep
# – PUNCT punct
# Где ADV advmod
# это PRON nsubj:pass
# видано VERB parataxis
# , PUNCT punct
# чтобы SCONJ mark
# свистки NOUN nsubj
# плавали VERB advcl
# ! PUNCT punct
# Зато CCONJ cc
# рыбку NOUN obj
# может VERB ROOT
# кот NOUN nsubj
# съесть VERB xcomp
# , PUNCT punct
# вот PART advmod
# и PART advmod
# не PART advmod
# будет AUX cop
# у ADP case
# тебя PRON obl
# ни CCONJ cc
# свистка NOUN nsubj
# , PUNCT punct
# ни CCONJ cc
# рыбки NOUN conj
# . PUNCT punct
# А CCONJ cc
# свисток NOUN obj
# кот NOUN nsubj
# не PART advmod
# съест VERB ROOT
# – PUNCT punct
# он PRON nsubj
# железный ADJ parataxis
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Мне PRON iobj
# мама NOUN nsubj
# не PART advmod
# позволяет VERB parataxis
# меняться VERB xcomp
# . PUNCT punct
# Она PRON nsubj
# говорит VERB ROOT
# , PUNCT punct
# что SCONJ mark
# сама ADJ acl
# купит VERB ccomp
# , PUNCT punct
# если SCONJ mark
# мне PRON iobj
# что PRON nsubj
# - PRON nsubj
# нибудь PRON iobj
# надо ADV advcl
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# сказал VERB parataxis
# Виталик PROPN nsubj
# . PUNCT punct
#
#
#
#
#
#
#
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Где ADV advmod
# же PART advmod
# она PRON nsubj
# купит VERB conj
# такой DET det
# свисток NOUN obj
# ? PUNCT punct
#   SPACE dep
# – PUNCT punct
# ответил VERB parataxis
# Серёжа PROPN iobj
# . PUNCT punct
#   SPACE dep
# – PUNCT punct
# Такие DET det
# свистки NOUN nsubj
# не PART advmod
# продаются VERB conj
# . PUNCT punct
# Это PRON nsubj
# настоящий ADJ amod
# милиционерский ADJ amod
# свисток NOUN ROOT
# . PUNCT punct
# Я PRON nsubj
# как SCONJ mark
# выйду VERB advcl
# во ADP case
# двор NOUN obl
# да CCONJ cc
# как SCONJ case
# засвищу NOUN obl
# , PUNCT punct
# сразу ADV advmod
# все PRON nsubj
# подумают VERB ROOT
# , PUNCT punct
# что SCONJ mark
# милиционер NOUN nsubj
# пришёл VERB ccomp
# . PUNCT punct
#
#
#  SPACE dep
# Серёжа PROPN nsubj
# вынул VERB ROOT
# из ADP case
# кармана NOUN obl
# свисток NOUN obj
# и CCONJ cc
# засвистел VERB conj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# А CCONJ cc
# ну PART fixed
# , PUNCT punct
# дай VERB parataxis
# я PRON nsubj
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# попросил VERB parataxis
# Виталик PROPN nsubj
# . PUNCT punct
#
#
#  SPACE dep
# Он PRON nsubj
# взял VERB ROOT
# свисток NOUN obj
# и CCONJ cc
# подул VERB conj
# в ADP case
# него PRON obl
# . PUNCT punct
# Свисток NOUN nsubj
# звонко PROPN nmod
# , PUNCT punct
# переливчато PROPN nsubj
# засвистел VERB ROOT
# . PUNCT punct
# Виталику NOUN iobj
# очень ADV advmod
# понравилось VERB ROOT
# , PUNCT punct
# как SCONJ mark
# он PRON nsubj
# свистит VERB ccomp
# . PUNCT punct
# Ему PRON iobj
# захотелось VERB ROOT
# иметь VERB xcomp
# свисток NOUN obj
# , PUNCT punct
# но CCONJ cc
# он PRON nsubj
# не PART advmod
# мог VERB conj
# сразу ADV advmod
# решиться VERB xcomp
# и CCONJ cc
# сказал VERB conj
# : PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# А CCONJ cc
# где ADV advmod
# у ADP case
# тебя PRON obl
# будет AUX aux
# жить VERB parataxis
# рыбка NOUN nsubj
# ? PUNCT punct
# У ADP case
# тебя PRON obl
# ведь PART advmod
# аквариума NOUN nsubj
# нет VERB ROOT
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# А CCONJ cc
# я PRON nsubj
# посажу VERB ROOT
# её PRON obj
# в ADP case
# банку NOUN obl
# из ADP case
# - ADP case
# под ADP case
# варенья NOUN obl
# . PUNCT punct
# У ADP case
# нас PRON obl
# большая ADJ amod
# банка NOUN nsubj
# есть VERB ROOT
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Ну PART discourse
# ладно PART parataxis
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# согласился VERB ROOT
# Виталик PROPN nsubj
# . PUNCT punct
#
#
#  SPACE dep
# Ребята NOUN nsubj
# принялись VERB ROOT
# ловить VERB xcomp
# рыбку NOUN obj
# в ADP case
# аквариуме NOUN obl
# , PUNCT punct
# но CCONJ cc
# карась VERB nsubj
# плавал VERB conj
# быстро ADV advmod
# и CCONJ cc
# не PART advmod
# давался VERB conj
# в ADP case
# руки NOUN obl
# . PUNCT punct
#
#
#  SPACE dep
# Они PRON nsubj
# набрызгали VERB ROOT
# вокруг ADP case
# водой NOUN obl
# , PUNCT punct
# а CCONJ cc
#   SPACE dep
# Серёжа PROPN nsubj
# измочил VERB conj
# рукава NOUN obj
# до ADP case
# самых ADJ amod
# локтей NOUN obl
# . PUNCT punct
# Наконец ADV advmod
# ему PRON iobj
# удалось VERB ROOT
# схватить VERB csubj
# карасика NOUN obj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Есть VERB ROOT
# ! PUNCT punct
#   SPACE dep
# – PUNCT punct
# закричал VERB parataxis
# он PRON nsubj
# . PUNCT punct
#   SPACE dep
# – PUNCT punct
# Давай VERB ROOT
# сюда ADV advmod
# какую DET det
# - DET det
# нибудь DET det
# кружку NOUN obj
# с ADP case
# водой NOUN nmod
# ! PUNCT punct
# Я PRON nsubj
# посажу VERB ROOT
# туда ADV advmod
# рыбку NOUN obj
# . PUNCT punct
#
#
#  SPACE dep
# Виталик NOUN nsubj
# поскорей NOUN nmod
# налил VERB ROOT
# в ADP case
# кружку NOUN obl
# воды NOUN nmod
# . PUNCT punct
# Серёжа PROPN nsubj
# посадил VERB ROOT
# карася NOUN obj
# в ADP case
# кружку NOUN obl
# . PUNCT punct
# Ребята NOUN nsubj
# пошли VERB ROOT
# к ADP case
#   SPACE dep
# Серёже NOUN obl
# – PUNCT punct
# сажать VERB parataxis
# рыбку NOUN obj
# в ADP case
# банку NOUN obl
# . PUNCT punct
# Банка NOUN nsubj
# оказалась VERB ROOT
# не PART advmod
# очень ADV advmod
# большая ADJ xcomp
# , PUNCT punct
# и CCONJ cc
# карасику NOUN iobj
# в ADP case
# ней PRON nmod
# было AUX cop
# не PART advmod
# так ADV advmod
# просторно ADV conj
# , PUNCT punct
# как SCONJ case
# в ADP case
# аквариуме NOUN obl
# . PUNCT punct
# Ребята NOUN nsubj
# долго ADV advmod
# смотрели VERB ROOT
# , PUNCT punct
# как SCONJ advmod
# карасик NOUN nsubj
# плавает VERB ccomp
# в ADP case
# банке NOUN obl
# . PUNCT punct
# Серёжа PROPN nsubj
# радовался VERB ROOT
# , PUNCT punct
# а CCONJ cc
#   SPACE dep
# Виталику NOUN iobj
# было AUX cop
# жалко ADV conj
# , PUNCT punct
# что SCONJ mark
# теперь ADV advmod
# у ADP case
# него PRON obl
# не PART advmod
# будет VERB ccomp
# рыбки NOUN nsubj
# , PUNCT punct
# а CCONJ cc
# главное ADJ parataxis
# , PUNCT punct
# он PRON nsubj
# боялся VERB conj
# признаться VERB xcomp
# маме NOUN iobj
# , PUNCT punct
# что SCONJ mark
# променял VERB parataxis
# карасика NOUN obj
# на ADP case
# свисток NOUN obl
# . PUNCT punct
#
#
#  SPACE dep
# « PUNCT punct
# Ну PART discourse
# , PUNCT punct
# ничего PRON nsubj
# , PUNCT punct
# может VERB parataxis
# быть VERB xcomp
# , PUNCT punct
# мама NOUN nsubj
# и CCONJ cc
# не PART advmod
# заметит VERB ROOT
# сразу ADV advmod
# , PUNCT punct
# что SCONJ mark
# рыбка NOUN nsubj
# пропала VERB ccomp
# » PUNCT punct
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# подумал VERB parataxis
# Виталик PROPN nsubj
# и CCONJ cc
# пошёл VERB conj
# домой ADV advmod
# . PUNCT punct
#
#
#  SPACE dep
# Когда SCONJ mark
# он PRON nsubj
# вернулся VERB advcl
# , PUNCT punct
# мама NOUN nsubj
# уже ADV advmod
# была AUX cop
# дома ADV ROOT
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Где ADV ROOT
# же PART advmod
# твоя DET det
# рыбка NOUN nsubj
# ? PUNCT punct
#   SPACE dep
# – PUNCT punct
# спросила VERB parataxis
# она PRON nsubj
# . PUNCT punct
#
#
#  SPACE dep
# Виталик NOUN nsubj
# растерялся VERB ROOT
# и CCONJ cc
# не PART advmod
# знал VERB conj
# , PUNCT punct
# что SCONJ obj
# сказать VERB xcomp
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Может VERB parataxis
# быть VERB xcomp
# , PUNCT punct
# её PRON det
# Мурзик PROPN nsubj
# съел VERB conj
# ? PUNCT punct
#   SPACE dep
# – PUNCT punct
# спросила VERB parataxis
# мама NOUN nsubj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Не PART advmod
# знаю VERB ROOT
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# пробормотал VERB parataxis
# Виталик PROPN nsubj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Вот PART advmod
# видишь VERB parataxis
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# сказала VERB parataxis
# мама NOUN nsubj
# . PUNCT punct
#   SPACE dep
# – PUNCT punct
# Он PRON nsubj
# выбрал VERB ROOT
# - PART advmod
# таки PART advmod
# время NOUN obj
# , PUNCT punct
# когда SCONJ mark
# дома NOUN nsubj
# никого PRON nsubj
# не PART advmod
# было VERB acl
# , PUNCT punct
# и CCONJ cc
# выловил VERB conj
# из ADP case
# аквариума NOUN obl
# рыбку NOUN obj
# ! PUNCT punct
# Где ADV ROOT
# он PRON nsubj
# , PUNCT punct
# разбойник NOUN conj
# ? PUNCT punct
# Ну PART parataxis
# - NOUN nsubj
# ка NOUN parataxis
# , PUNCT punct
# найди VERB ROOT
# мне PRON iobj
# его PRON obj
# сейчас ADV advmod
# ! PUNCT punct
#
#
#
#
#
#
#
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Мурзик PROPN parataxis
# ! PUNCT punct
# Мурзик VERB nsubj
# ! PUNCT punct
#   SPACE dep
# – PUNCT punct
# стал VERB ROOT
# звать VERB xcomp
# Виталик PROPN obj
# , PUNCT punct
# но CCONJ cc
# кота NOUN nsubj
# нигде ADV advmod
# не PART advmod
# было VERB conj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Наверно ADV ROOT
# , PUNCT punct
# в ADP case
# форточку NOUN obl
# убежал VERB conj
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# сказала VERB conj
# мама NOUN nsubj
# . PUNCT punct
#   SPACE dep
# – PUNCT punct
# Пойди PROPN nsubj
# - PROPN nsubj
# ка PROPN parataxis
# во ADP case
# двор NOUN nmod
# , PUNCT punct
# позови NOUN ROOT
# его PRON obj
# . PUNCT punct
#
#
#  SPACE dep
# Виталик NOUN nsubj
# надел VERB ROOT
# пальто NOUN obj
# и CCONJ cc
# вышел VERB conj
# во ADP case
# двор NOUN obl
# . PUNCT punct
#
#
#  SPACE dep
# « PUNCT punct
# Вот PART advmod
# как ADV advmod
# нехорошо ADV advmod
# получилось VERB ROOT
# ! PUNCT punct
#   SPACE dep
# – PUNCT punct
# думал VERB parataxis
# он PRON nsubj
# . PUNCT punct
#   SPACE dep
# – PUNCT punct
# Теперь ADV advmod
# Мурзику PROPN iobj
# из ADP case
# - ADP case
# за ADP case
# меня PRON obl
# достанется VERB ROOT
# » PUNCT punct
# . PUNCT punct
#
#
#  SPACE dep
# Он PRON nsubj
# хотел VERB ROOT
# вернуться VERB xcomp
# домой ADV advmod
# и CCONJ cc
# сказать VERB conj
# , PUNCT punct
# что SCONJ mark
# Мурзика PROPN nsubj
# во ADP case
# дворе NOUN obl
# нет VERB ccomp
# , PUNCT punct
# но CCONJ cc
# тут ADV advmod
# Мурзик PROPN nsubj
# выскочил VERB conj
# из ADP case
# отдушины NOUN obl
# , PUNCT punct
# которая PRON nsubj
# была AUX cop
# под ADP case
# домом NOUN acl:relcl
# , PUNCT punct
# и CCONJ cc
# быстро ADV advmod
# побежал VERB conj
# к ADP case
# двери NOUN obl
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Мурзинька PROPN ROOT
# , PUNCT punct
# не PART advmod
# ходи VERB conj
# домой ADV advmod
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# сказал VERB parataxis
# Виталик PROPN nsubj
# . PUNCT punct
#   SPACE dep
# – PUNCT punct
# Тебе PRON nsubj
# попадёт VERB ROOT
# от ADP case
# мамы NOUN obl
# . PUNCT punct
#
#
#  SPACE dep
# Мурзик PROPN nsubj
# замурлыкал VERB ROOT
# , PUNCT punct
# принялся VERB conj
# тереться VERB xcomp
# спинкой NOUN xcomp
# об ADP case
# ноги NOUN nmod
# Виталика PROPN nmod
# , PUNCT punct
# потом ADV advmod
# поглядел VERB conj
# на ADP case
# закрытую VERB amod
# дверь NOUN obl
# и CCONJ cc
# потихоньку ADV advmod
# мяукнул VERB conj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Не PART advmod
# понимаешь VERB parataxis
# , PUNCT punct
# глупый ADJ conj
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# сказал VERB parataxis
# Виталик PROPN nsubj
# . PUNCT punct
#   SPACE dep
# – PUNCT punct
# Тебе PRON iobj
# ведь PART advmod
# человеческим ADJ amod
# языком NOUN obl
# говорят VERB conj
# , PUNCT punct
# что SCONJ mark
# нельзя ADV ccomp
# домой ADV advmod
# . PUNCT punct
#
#
#  SPACE dep
# Но CCONJ cc
# Мурзик PROPN nsubj
# , PUNCT punct
# конечно ADV parataxis
# , PUNCT punct
# ничего PRON obj
# не PART advmod
# понимал VERB ROOT
# . PUNCT punct
# Он PRON nsubj
# ласкался VERB ROOT
# к ADP case
#   SPACE dep
# Виталику PROPN obl
# , PUNCT punct
# тёрся ADJ conj
# об ADP case
# него PRON obl
# боками NOUN iobj
# и CCONJ cc
# потихоньку ADV advmod
# бодал VERB conj
# его PRON obj
# головой NOUN iobj
# , PUNCT punct
# будто SCONJ mark
# торопил VERB advcl
# поскорей NOUN obj
# открыть VERB xcomp
# дверь NOUN obj
# . PUNCT punct
# Виталик NOUN nsubj
# стал VERB ROOT
# отталкивать VERB xcomp
# его PRON obj
# от ADP case
# двери NOUN obl
# , PUNCT punct
# но CCONJ cc
# Мурзик PROPN nsubj
# не PART advmod
# хотел VERB conj
# уходить VERB xcomp
# . PUNCT punct
# Тогда ADV advmod
# Виталик PROPN nsubj
# спрятался VERB ROOT
# от ADP case
# него PRON obl
# за ADP case
# дверь NOUN obl
# . PUNCT punct
#
#
#  SPACE dep
# « PUNCT punct
# Мяу NOUN ROOT
# ! PUNCT punct
# » PUNCT punct
#   SPACE dep
# – PUNCT punct
# закричал VERB parataxis
# Мурзик PROPN nsubj
# под ADP case
# дверью NOUN obl
# . PUNCT punct
#
#
#  SPACE dep
# Виталик NOUN nsubj
# поскорей NOUN nmod
# вышел VERB ROOT
# обратно ADV advmod
# : PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Тише PROPN parataxis
# ! PUNCT punct
# Кричит VERB ROOT
# тут ADV advmod
# ! PUNCT punct
# Вот PART advmod
# мама NOUN nsubj
# услышит VERB ROOT
# , PUNCT punct
# тогда ADV advmod
# узнаешь VERB conj
# ! PUNCT punct
#
#
#  SPACE dep
# Он PRON nsubj
# схватил VERB ROOT
# Мурзика PROPN obj
# и CCONJ cc
# принялся VERB conj
# запихивать VERB xcomp
# его PRON obj
# обратно ADV advmod
# в ADP case
# отдушину NOUN obl
# под ADP case
# домом NOUN nmod
# , PUNCT punct
# из ADP case
# которой PRON obl
# Мурзик PROPN nsubj
# только PART advmod
# что SCONJ fixed
# вылез VERB acl:relcl
# . PUNCT punct
# Мурзик PROPN nsubj
# упирался VERB ROOT
# всеми DET det
# четырьмя NUM nummod
# лапами NOUN obl
# и CCONJ cc
# не PART advmod
# хотел VERB conj
# лезть VERB xcomp
# в ADP case
# отдушину NOUN obl
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Лезь PROPN obj
# , PUNCT punct
# глупый ADJ conj
# ! PUNCT punct
#   SPACE dep
# – PUNCT punct
# уговаривал VERB parataxis
# его PRON obj
# Виталик PROPN nsubj
# . PUNCT punct
#   SPACE dep
# – PUNCT punct
# Посиди PROPN obj
# там ADV advmod
# пока ADV advmod
# . PUNCT punct
#
#
#  SPACE dep
# Наконец ADV advmod
# он PRON nsubj
# его PRON obj
# целиком ADV advmod
# запихал VERB ROOT
# в ADP case
# отдушину NOUN obl
# . PUNCT punct
# Только PART advmod
# хвост NOUN nsubj
# Мурзика PROPN nmod
# остался VERB ROOT
# торчать VERB xcomp
# снаружи ADV advmod
# . PUNCT punct
# Некоторое DET det
# время NOUN obl
# Мурзик PROPN nsubj:pass
# сердито VERB advmod
# вертел VERB ROOT
# хвостом NOUN obl
# , PUNCT punct
# потом ADV advmod
# и PART advmod
# хвост NOUN nsubj
# скрылся VERB conj
# в ADP case
# отдушине NOUN obl
# . PUNCT punct
# Виталик NOUN nsubj
# обрадовался VERB ROOT
# . PUNCT punct
# Он PRON nsubj
# думал VERB ROOT
# , PUNCT punct
# что SCONJ mark
# котёнок NOUN nsubj
# останется VERB ccomp
# теперь ADV advmod
# сидеть VERB xcomp
# в ADP case
# подвале NOUN obl
# , PUNCT punct
# но CCONJ cc
# тут ADV advmod
# Мурзик PROPN nsubj
# снова ADV advmod
# выглянул VERB conj
# из ADP case
# дыры NOUN obl
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Ну PART discourse
# куда ADV advmod
# же PART advmod
# ты PRON nsubj
# лезешь VERB parataxis
# , PUNCT punct
# глупая VERB advcl
# голова NOUN obj
# ! PUNCT punct
#   SPACE dep
# – PUNCT punct
# зашипел VERB parataxis
# Виталик PROPN nsubj
# и CCONJ cc
# загородил VERB conj
# выход NOUN obj
# руками NOUN iobj
# . PUNCT punct
#   SPACE dep
# – PUNCT punct
# Говорят VERB ROOT
# же PART advmod
# тебе PRON iobj
# : PUNCT punct
# нельзя ADV parataxis
# домой ADV advmod
# идти VERB csubj
# . PUNCT punct
#
#
#  SPACE dep
# « PUNCT punct
# Мяу NOUN ROOT
# ! PUNCT punct
# » PUNCT punct
#   SPACE dep
# – PUNCT punct
# закричал VERB parataxis
# Мурзик PROPN nsubj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Вот PART appos
# тебе PRON iobj
# и PART cc
# « PUNCT punct
# мяу PROPN conj
# » PUNCT punct
# ! PUNCT punct
#   SPACE dep
# – PUNCT punct
# передразнил VERB parataxis
# его PRON obj
# Виталик PROPN nsubj
# . PUNCT punct
#   SPACE dep
# – PUNCT punct
# Ну PART discourse
# что PRON obj
# мне PRON iobj
# теперь ADV advmod
# делать VERB csubj
# с ADP case
# тобой PRON obl
# ? PUNCT punct
#
#
#  SPACE dep
# Он PRON nsubj
# стал VERB ROOT
# оглядываться VERB xcomp
# вокруг ADV advmod
# и CCONJ cc
# искать VERB conj
# , PUNCT punct
# чем PRON obl
# бы AUX aux
# закрыть VERB ccomp
# дыру NOUN obj
# . PUNCT punct
# Рядом ADV advmod
# лежал VERB ROOT
# кирпич NOUN nsubj
# . PUNCT punct
# Виталик NOUN nsubj
# поднял VERB ROOT
# его PRON obj
# и CCONJ cc
# закрыл VERB conj
# дыру NOUN obj
# кирпичом NOUN iobj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Вот PART advmod
# теперь ADV advmod
# не PART advmod
# вылезешь VERB conj
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# сказал VERB parataxis
# он PRON nsubj
# . PUNCT punct
#   SPACE dep
# – PUNCT punct
# Посиди PROPN ROOT
# там ADV advmod
# , PUNCT punct
# в ADP case
# подвале NOUN conj
# , PUNCT punct
# а CCONJ cc
# завтра ADV advmod
# мама NOUN nsubj
# забудет VERB conj
# про ADP case
# рыбку NOUN obl
# и CCONJ cc
# я PRON nsubj
# тебя PRON obj
# выпущу VERB conj
# . PUNCT punct
#
#
#  SPACE dep
# Виталик NOUN nsubj
# вернулся VERB ROOT
# домой ADV advmod
# и CCONJ cc
# сказал VERB conj
# , PUNCT punct
# что SCONJ mark
# Мурзика PROPN nsubj
# во ADP case
# дворе NOUN obl
# нет VERB ccomp
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Ничего PRON nsubj
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# сказала VERB parataxis
# мама NOUN nsubj
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# вернётся VERB conj
# . PUNCT punct
# Я PRON nsubj
# всё PART advmod
# равно ADJ fixed
# не PART advmod
# прощу VERB ROOT
# ему PRON iobj
# этого PRON obj
# . PUNCT punct
#
#
#  SPACE dep
# За ADP case
# обедом NOUN obl
# Виталик PROPN nsubj
# сидел VERB ROOT
# грустный ADJ nsubj
# и CCONJ cc
# даже PART advmod
# не PART advmod
# хотел VERB conj
# ничего PRON obj
# есть VERB xcomp
# . PUNCT punct
#
#
#  SPACE dep
# « PUNCT punct
# Я PRON nsubj
# вот PART advmod
# обедаю VERB ROOT
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# думал VERB parataxis
# он PRON nsubj
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# а CCONJ cc
#   SPACE dep
# Мурзик PROPN appos
# , PUNCT punct
# бедный ADJ conj
# , PUNCT punct
# в ADP case
# подвале NOUN obl
# сидит VERB conj
# » PUNCT punct
# . PUNCT punct
#
#
#  SPACE dep
# Когда SCONJ mark
# мама NOUN nsubj
# вышла VERB advcl
# из ADP case
# - ADP case
# за ADP case
# стола NOUN obl
# , PUNCT punct
# он PRON nsubj
# незаметно ADV advmod
# сунул VERB ROOT
# в ADP case
# карман NOUN obl
# котлету NOUN obj
# и CCONJ cc
# пошёл VERB conj
# во ADP case
# двор NOUN obl
# . PUNCT punct
# Там ADV advmod
# он PRON nsubj
# отодвинул VERB ROOT
# кирпич NOUN obj
# , PUNCT punct
# которым PRON iobj
# была AUX aux:pass
# закрыта VERB acl:relcl
# отдушина NOUN nsubj:pass
# , PUNCT punct
# и CCONJ cc
# потихоньку ADV advmod
# позвал VERB conj
# : PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Мурзик PROPN parataxis
# ! PUNCT punct
# Мурзик VERB ROOT
# ! PUNCT punct
#
#
#  SPACE dep
# Но CCONJ cc
# Мурзик PROPN nsubj
# не PART advmod
# отзывался VERB ROOT
# . PUNCT punct
# Виталик NOUN nsubj
# нагнулся VERB ROOT
# и CCONJ cc
# заглянул VERB conj
# в ADP case
# дыру NOUN obl
# . PUNCT punct
# В ADP case
# подвале NOUN obl
# было AUX cop
# темно ADJ ROOT
# и CCONJ cc
# ничего PRON nsubj
# не PART advmod
# было AUX cop
# видно ADV conj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Мурзик PROPN ROOT
# ! PUNCT punct
# Мурзинька PROPN ROOT
# ! PUNCT punct
#   SPACE dep
# – PUNCT punct
# звал VERB parataxis
# Виталик PROPN nsubj
# . PUNCT punct
#   SPACE dep
# – PUNCT punct
# Я PRON nsubj
# тебе PRON iobj
# котлету VERB iobj
# принёс NOUN ROOT
# ! PUNCT punct
#
#
#  SPACE dep
# Мурзик PROPN nsubj
# не PART advmod
# вылезал VERB ROOT
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Не PART advmod
# хочешь VERB obj
# – PUNCT punct
# ну PART discourse
# и CCONJ advmod
# сиди NOUN parataxis
# , PUNCT punct
# глупая VERB amod
# голова NOUN conj
# ! PUNCT punct
#   SPACE dep
# – PUNCT punct
# сказал VERB parataxis
# Виталик PROPN nsubj
# и CCONJ cc
# вернулся VERB conj
# домой ADV advmod
# . PUNCT punct
#
#
#  SPACE dep
# Дома NOUN nsubj
# без ADP case
# Мурзика PROPN nmod
# ему PRON iobj
# было AUX cop
# скучно ADJ ROOT
# . PUNCT punct
# На ADP case
# душе NOUN obl
# было AUX cop
# как ADV advmod
# - ADV advmod
# то ADV advmod
# нехорошо ADJ ROOT
# , PUNCT punct
# потому ADV mark
# что SCONJ fixed
# он PRON nsubj
# обманул VERB advcl
# маму NOUN obj
# . PUNCT punct
# Мама NOUN nsubj
# заметила VERB ROOT
# , PUNCT punct
# что SCONJ mark
# он PRON nsubj
# грустный ADJ ccomp
# , PUNCT punct
# и CCONJ cc
# сказала VERB conj
# : PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Не PART advmod
# горюй VERB parataxis
# ! PUNCT punct
# Я PRON nsubj
# тебе PRON iobj
# другую ADJ amod
# рыбку NOUN obj
# куплю VERB ROOT
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Не PART advmod
# надо ADV ROOT
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# сказал VERB parataxis
# Виталик PROPN nsubj
# . PUNCT punct
#
#
#  SPACE dep
# Он PRON nsubj
# уже ADV advmod
# хотел VERB ROOT
# признаться VERB xcomp
# маме NOUN iobj
# во ADP case
# всём ADV obl
# , PUNCT punct
# но CCONJ cc
# у ADP case
# него PRON obl
# не PART advmod
# хватило VERB conj
# смелости NOUN nsubj
# , PUNCT punct
# и CCONJ cc
# он PRON nsubj
# ничего PRON obj
# не PART advmod
# сказал VERB conj
# . PUNCT punct
# Тут ADV advmod
# за ADP case
# окном NOUN obl
# послышался VERB ROOT
# шорох NOUN nsubj
# и CCONJ cc
# раздался VERB conj
# крик NOUN nsubj
# : PUNCT punct
#
#
#  SPACE dep
# « PUNCT punct
# Мяу INTJ parataxis
# ! PUNCT punct
# » PUNCT punct
#
#
#  SPACE dep
# Виталик PROPN nsubj
# посмотрел VERB conj
# в ADP case
# окно NOUN obl
# и CCONJ cc
# увидел VERB conj
# снаружи ADV advmod
# на ADP case
# подоконнике NOUN obl
# Мурзика PROPN nmod
# . PUNCT punct
# Видно ADV parataxis
# , PUNCT punct
# он PRON nsubj
# вылез VERB ROOT
# из ADP case
# подвала NOUN obl
# через ADP case
# другую ADJ amod
# дырку NOUN obl
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# А CCONJ ROOT
# ! PUNCT punct
# Пришёл VERB ROOT
# наконец ADV advmod
# , PUNCT punct
# разбойник NOUN parataxis
# ! PUNCT punct
#   SPACE dep
# – PUNCT punct
# сказала VERB parataxis
# мама NOUN nsubj
# . PUNCT punct
#   SPACE dep
# – PUNCT punct
# Иди NOUN ROOT
# - PROPN ROOT
# ка PROPN ROOT
# сюда ADV advmod
# , PUNCT punct
# иди VERB conj
# ! PUNCT punct
#
#
#  SPACE dep
# Мурзик PROPN nsubj
# прыгнул VERB ROOT
# в ADP case
# открытую ADJ amod
# форточку NOUN obl
# и CCONJ cc
# очутился VERB conj
# в ADP case
# комнате NOUN obl
# . PUNCT punct
# Мама NOUN nsubj
# хотела VERB ROOT
# схватить VERB xcomp
# его PRON obj
# , PUNCT punct
# но CCONJ cc
# он PRON nsubj
# , PUNCT punct
# видно ADV parataxis
# , PUNCT punct
# догадался VERB conj
# , PUNCT punct
# что SCONJ mark
# его PRON obj
# хотят VERB ccomp
# наказать VERB xcomp
# , PUNCT punct
# и CCONJ cc
# шмыгнул VERB conj
# под ADP case
# стол NOUN obl
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Ишь PROPN parataxis
# ты PRON nsubj
# , PUNCT punct
# хитрец NOUN appos
# какой DET det
# ! PUNCT punct
#   SPACE dep
# – PUNCT punct
# сказала VERB parataxis
# мама NOUN nsubj
# . PUNCT punct
#   SPACE dep
# – PUNCT punct
# Чувствует VERB ROOT
# , PUNCT punct
# что SCONJ mark
# виноват ADJ ccomp
# . PUNCT punct
# Ну PART parataxis
# - NOUN parataxis
# ка NOUN parataxis
# , PUNCT punct
# поймай VERB ROOT
# его PRON obj
# . PUNCT punct
#
#
#  SPACE dep
# Виталик NOUN nsubj
# полез VERB ROOT
# под ADP case
# стол NOUN obl
# . PUNCT punct
# Мурзик PROPN nsubj
# увидел VERB ROOT
# его PRON obj
# и CCONJ cc
# юркнул VERB conj
# под ADP case
# диван NOUN obl
# . PUNCT punct
# Виталик NOUN nsubj
# был AUX cop
# рад ADJ ROOT
# , PUNCT punct
# что SCONJ mark
# Мурзик PROPN nsubj
# удрал VERB ccomp
# от ADP case
# него PRON obl
# . PUNCT punct
# Он PRON nsubj
# полез VERB ROOT
# под ADP case
# диван NOUN obl
# и CCONJ cc
# нарочно ADV advmod
# старался VERB conj
# шуметь VERB xcomp
# , PUNCT punct
# чтобы SCONJ mark
# Мурзик PROPN nsubj
# услышал VERB advcl
# и CCONJ cc
# успел VERB conj
# убежать VERB xcomp
# . PUNCT punct
# Мурзик PROPN nsubj
# выскочил VERB ROOT
# из ADP case
# - ADP case
# под ADP case
# дивана NOUN obl
# . PUNCT punct
# Виталик NOUN nsubj
# погнался VERB ROOT
# за ADP case
# ним PRON obl
# и CCONJ cc
# принялся VERB conj
# бегать VERB xcomp
# по ADP case
# всей DET det
# комнате NOUN obl
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Что SCONJ obj
# ты PRON nsubj
# такой DET det
# шум NOUN obj
# поднял VERB conj
# ? PUNCT punct
# Разве PART advmod
# его PRON obj
# так ADV advmod
# поймаешь VERB ROOT
# ! PUNCT punct
#   SPACE dep
# – PUNCT punct
# сказала VERB parataxis
# мама NOUN nsubj
# . PUNCT punct
#
#
#  SPACE dep
# Тут ADV advmod
# Мурзик PROPN nsubj
# прыгнул VERB ROOT
# на ADP case
# подоконник NOUN obl
# , PUNCT punct
# где ADV advmod
# стоял VERB acl:relcl
# аквариум NOUN nsubj
# , PUNCT punct
# и CCONJ cc
# хотел VERB conj
# выскочить VERB xcomp
# обратно ADV advmod
# в ADP case
# форточку NOUN obl
# , PUNCT punct
# но CCONJ cc
# сорвался VERB conj
# и CCONJ advmod
# с ADP case
# размаху NOUN obl
# как SCONJ mark
# плюхнется VERB advcl
# в ADP case
# аквариум NOUN obl
# ! PUNCT punct
# Вода NOUN nsubj
# так ADV advmod
# и PART fixed
# брызнула VERB ROOT
# в ADP case
# разные ADJ amod
# стороны NOUN obl
# . PUNCT punct
# Мурзик PROPN nsubj
# выскочил VERB ROOT
# из ADP case
# аквариума NOUN obl
# и CCONJ cc
# давай VERB conj
# отряхиваться VERB xcomp
# . PUNCT punct
# Тут ADV advmod
# мама NOUN nsubj
# и CCONJ cc
# схватила VERB ROOT
# его PRON obj
# за ADP case
# шиворот NOUN obl
# : PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Вот PART advmod
# я PRON nsubj
# тебя PRON obj
# проучу VERB parataxis
# как SCONJ mark
# следует VERB obl
# ! PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Мамочка NOUN parataxis
# , PUNCT punct
# миленькая ADJ conj
# , PUNCT punct
# не PART advmod
# бей NOUN conj
# Мурзика PROPN obj
# ! PUNCT punct
#   SPACE dep
# – PUNCT punct
# заплакал VERB parataxis
# Виталик PROPN nsubj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Нечего VERB ROOT
# его PRON obj
# жалеть VERB csubj
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# сказала VERB parataxis
# мама NOUN nsubj
# . PUNCT punct
#   SPACE dep
# – PUNCT punct
# Он PRON nsubj
# ведь PART advmod
# не PART advmod
# пожалел VERB ROOT
# рыбку NOUN obj
# ! PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Мамочка NOUN parataxis
# , PUNCT punct
# он PRON nsubj
# не PART advmod
# виноват ADJ conj
# ! PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Как ADV advmod
# же PART advmod
# « PUNCT punct
# не PART advmod
# виноват ADJ parataxis
# » PUNCT punct
# ? PUNCT punct
# А CCONJ cc
# кто PRON nsubj
# карася PROPN obj
# съел VERB ROOT
# ? PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Это PRON nsubj
# не PART advmod
# он PRON nsubj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# А CCONJ cc
# кто PRON ROOT
# же PART advmod
# ? PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Это PRON nsubj
# я PRON nsubj
# … PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Ты PRON nsubj
# съел VERB ROOT
# ? PUNCT punct
#   SPACE dep
# – PUNCT punct
# удивилась VERB parataxis
# мама NOUN nsubj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Нет PART parataxis
# , PUNCT punct
# я PRON nsubj
# не PART advmod
# съел VERB ROOT
# . PUNCT punct
# Я PRON nsubj
# его PRON obj
# на ADP case
# свисток NOUN obl
# променял VERB ROOT
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# На ADP case
# какой DET det
# свисток NOUN obj
# ? PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Вот PART advmod
# на ADP case
# этот DET det
# . PUNCT punct
#
#
#  SPACE dep
# Виталик PROPN nsubj
# вынул VERB ROOT
# из ADP case
# кармана NOUN obl
# свисток NOUN obj
# и CCONJ cc
# показал VERB conj
# маме NOUN iobj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Как ADV advmod
# же PART advmod
# тебе PRON iobj
# не PART advmod
# стыдно ADV advmod
# ? PUNCT punct
#   SPACE dep
# – PUNCT punct
# сказала VERB parataxis
# мама NOUN nsubj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Я PRON nsubj
# нечаянно ADV ROOT
# . PUNCT punct
# Серёжа PROPN iobj
# сказал VERB ROOT
# : PUNCT punct
# « PUNCT punct
# Давай VERB parataxis
# меняться VERB xcomp
# » PUNCT punct
# , PUNCT punct
# я PRON nsubj
# и PART advmod
#   SPACE dep
# поменялся VERB conj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Я PRON nsubj
# не PART advmod
# о ADP case
# том PRON obl
# говорю VERB parataxis
# ! PUNCT punct
# Я PRON nsubj
# говорю VERB ROOT
# , PUNCT punct
# почему ADV advmod
# ты PRON nsubj
# не PART advmod
# сказал VERB ccomp
# правду NOUN obj
# ? PUNCT punct
# Я PRON nsubj
# ведь PART advmod
# на ADP case
# Мурзика PROPN obl
# подумала VERB ROOT
# . PUNCT punct
# Разве PART advmod
# честно ADV advmod
# ...
#   SPACE dep
# Я PRON nsubj
# больше ADV advmod
# не PART parataxis
# буду AUX cop
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Ну PART discourse
# , PUNCT punct
# смотри VERB ROOT
# ! PUNCT punct
# Только PART advmod
# потому ADV advmod
# прощаю VERB ROOT
# , PUNCT punct
# что SCONJ mark
# ты PRON nsubj
# всё PART advmod
# - PART advmod
# таки PART advmod
# сам ADJ acl
# признался VERB ccomp
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# сказала VERB parataxis
# мама NOUN nsubj
# . PUNCT punct
#
#
#  SPACE dep
# Виталик NOUN nsubj
# взял VERB ROOT
# Мурзика PROPN obj
# и CCONJ cc
# понёс NOUN conj
# к ADP case
# батарее NOUN obl
# сушиться VERB xcomp
# . PUNCT punct
# Он PRON nsubj
# посадил VERB ROOT
# его PRON obj
# на ADP case
# скамеечке NOUN obl
# и CCONJ cc
# сел VERB conj
# рядом ADV advmod
# с ADP case
# ним PRON obl
# . PUNCT punct
# Мокрая ADJ amod
# шерсть NOUN nsubj
# на ADP case
# Мурзике PROPN nmod
# торчала VERB ROOT
# в ADP case
# разные ADJ amod
# стороны NOUN obl
# , PUNCT punct
# как SCONJ case
# иголки NOUN obl
# у ADP case
# ёжика PROPN nmod
# , PUNCT punct
# и CCONJ cc
# от ADP case
# этого PRON obl
# Мурзик PROPN nsubj
# казался VERB conj
# таким DET det
# худым ADJ iobj
# - ADJ iobj
# худым ADJ iobj
# , PUNCT punct
# будто SCONJ mark
# целую ADJ amod
# неделю NOUN obj
# совсем ADV advmod
# ничего PRON obj
# не PART advmod
# ел VERB advcl
# . PUNCT punct
# Виталик NOUN nsubj
# вынул VERB ROOT
# из ADP case
# кармана NOUN obl
# котлету NOUN obj
# и CCONJ cc
# положил VERB conj
# перед ADP case
# Мурзиком PROPN obl
# . PUNCT punct
# Мурзик PROPN nsubj
# съел VERB ROOT
# котлету NOUN obj
# , PUNCT punct
# потом ADV advmod
# забрался VERB conj
# на ADP case
# колени NOUN obl
# к ADP case
#   SPACE dep
# Виталику PROPN obl
# , PUNCT punct
# свернулся VERB conj
# калачиком NOUN obl
# и CCONJ cc
# замурлыкал VERB conj
# свою DET det
# песенку NOUN obj
# . PUNCT punct
#
#
#
#
#
#
#
#
#
#
#  SPACE dep
# Три NUM nummod:gov
# охотника NOUN nsubj
#
#
#
#  SPACE dep
# Жили PROPN appos
# - PUNCT appos
# были AUX ROOT
# три NUM nummod:gov
# весёлых ADJ amod
# охотника NOUN nsubj
# : PUNCT punct
# дядя NOUN parataxis
# Ваня PROPN appos
# , PUNCT punct
# дядя NOUN conj
# Федя PROPN appos
# да PART appos
# дядя NOUN appos
# Кузьма PROPN appos
# . PUNCT punct
# Вот PART advmod
# пошли VERB ROOT
# они PRON nsubj
# в ADP case
# лес NOUN obl
# . PUNCT punct
# Ходили PROPN ROOT
# , PUNCT punct
# ходили VERB conj
# , PUNCT punct
# много ADV advmod
# разных ADJ amod
# зверушек NOUN obl
# видели VERB conj
# , PUNCT punct
# но CCONJ cc
# никого PRON obj
# не PART advmod
# убили VERB conj
# . PUNCT punct
# И CCONJ cc
# решили VERB ROOT
# устроить VERB xcomp
# привал VERB obj
# : PUNCT punct
# отдохнуть VERB parataxis
# , PUNCT punct
# значит VERB parataxis
# . PUNCT punct
# Уселись VERB ROOT
# на ADP case
# зелёной ADJ amod
# лужайке NOUN obl
# и CCONJ cc
# стали VERB conj
# рассказывать VERB xcomp
# друг PRON iobj
# другу PRON fixed
# разные ADJ amod
# интересные ADJ amod
# случаи NOUN obj
# . PUNCT punct
#
#
#  SPACE dep
# Первым ADJ obl
# рассказал VERB ROOT
# охотник NOUN nsubj
# дядя NOUN nmod
# Ваня PROPN appos
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Вот PART advmod
# послушайте VERB parataxis
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# сказал VERB parataxis
# он PRON nsubj
# . PUNCT punct
#   SPACE dep
# – PUNCT punct
# Давно ADV advmod
# это PRON nsubj
# было AUX ROOT
# . PUNCT punct
# Пошёл VERB obj
# я PRON nsubj
# как ADV advmod
# - ADV advmod
# то ADV advmod
# зимою VERB ROOT
# в ADP case
# лес NOUN obl
# , PUNCT punct
# а CCONJ cc
# ружья NOUN nsubj
# у ADP case
# меня PRON nmod
# в ADP case
# ту DET det
# пору NOUN obl
# не PART advmod
# было VERB conj
# : PUNCT punct
# я PRON nsubj
#   SPACE dep
# тогда ADV advmod
# маленький ADJ parataxis
# был AUX cop
# . PUNCT punct
# Вдруг ADV advmod
# смотрю VERB ROOT
# – PUNCT punct
# волк NOUN nsubj
# . PUNCT punct
# Огромный ADJ amod
# такой DET ROOT
# . PUNCT punct
# Я PRON nsubj
# от ADP case
# него PRON obl
# бежать VERB ROOT
# . PUNCT punct
# А CCONJ cc
# волк NOUN obj
# - NOUN obj
# то PRON obj
# , PUNCT punct
# видать VERB csubj
# , PUNCT punct
# заметил VERB ROOT
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# без ADP case
# ружья NOUN ccomp
# . PUNCT punct
# Как SCONJ mark
# побежит VERB ROOT
# за ADP case
# мной PRON obl
# ! PUNCT punct
#
#
#  SPACE dep
# « PUNCT punct
# Ну PART parataxis
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# думаю VERB parataxis
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# не PART advmod
# удрать VERB ROOT
# мне PRON iobj
# от ADP case
# него PRON obl
# » PUNCT punct
# . PUNCT punct
#
#
#  SPACE dep
# Смотрю VERB nsubj
# – PUNCT punct
# дерево NOUN ROOT
# . PUNCT punct
# Я PRON nsubj
# на ADP case
# дерево NOUN ROOT
# . PUNCT punct
# Волк NOUN nsubj
# хотел VERB ROOT
# цапнуть VERB xcomp
# меня PRON obj
# , PUNCT punct
# да CCONJ cc
# не PART advmod
# успел VERB conj
# . PUNCT punct
# Только PART advmod
# штаны NOUN nsubj
# сзади ADV advmod
# зубами NOUN obl
# порвал VERB ROOT
# . PUNCT punct
# Залез VERB ROOT
# я PRON nsubj
# на ADP case
#   SPACE dep
# дерево NOUN obl
# , PUNCT punct
# сижу VERB conj
# на ADP case
# ветке NOUN obl
# и CCONJ cc
# трясусь VERB conj
# от ADP case
# страха NOUN obl
# . PUNCT punct
# А CCONJ cc
# волк NOUN nsubj
# сидит VERB ROOT
# внизу ADV advmod
# на ADP case
# снегу NOUN obl
# , PUNCT punct
# поглядывает VERB conj
# на ADP case
# меня PRON obl
# и CCONJ cc
# облизывается VERB conj
# . PUNCT punct
#
#
#  SPACE dep
# Я PRON nsubj
# думаю VERB ROOT
# : PUNCT punct
# « PUNCT punct
# Ладно PART parataxis
# , PUNCT punct
# посижу VERB parataxis
# здесь ADV advmod
# до ADP case
# вечера NOUN obl
# . PUNCT punct
# Ночью NOUN obl
# волчишка NOUN nsubj
# заснёт NOUN ROOT
# , PUNCT punct
# я PRON nsubj
# от ADP case
# него PRON obl
# удеру NOUN conj
# » PUNCT punct
# . PUNCT punct
#
#
#  SPACE dep
# К ADP case
# вечеру NOUN obl
# , PUNCT punct
# однако ADV parataxis
# , PUNCT punct
# ещё ADV advmod
# один NUM nummod
# волк NOUN nsubj
# пришёл VERB ROOT
# . PUNCT punct
# И CCONJ cc
# стали VERB ROOT
# они PRON nsubj
# меня PRON obj
# вдвоём NOUN obj
# караулить VERB xcomp
# . PUNCT punct
# Один NUM nummod
# волк NOUN nsubj
# спит VERB ROOT
# , PUNCT punct
# а CCONJ cc
# другой ADJ amod
# стережёт NOUN conj
# , PUNCT punct
# чтоб SCONJ mark
# я PRON nsubj
# не PART advmod
#   SPACE dep
# сбежал VERB advcl
# . PUNCT punct
# Немного ADV advmod
# погодя VERB ROOT
# пришёл VERB obl
# третий ADJ amod
# волк NOUN nsubj
# . PUNCT punct
# Потом ADV advmod
# ещё ADV ROOT
# и CCONJ cc
# ещё ADV conj
# . PUNCT punct
# И CCONJ cc
# собралась VERB ROOT
# под ADP case
# деревом NOUN obl
# целая ADJ amod
# волчья ADJ amod
# стая NOUN nsubj
# . PUNCT punct
# Сидят VERB ROOT
# все PRON det
# да PART advmod
# зубами NOUN obl
# щёлкают VERB conj
# на ADP case
# меня PRON obl
# . PUNCT punct
# Ждут VERB ROOT
# , PUNCT punct
# когда SCONJ mark
# я PRON nsubj
# свалюсь VERB advcl
# к ADP case
# ним PRON obl
# сверху ADV advmod
# . PUNCT punct
#
#
#  SPACE dep
# Под ADP case
# утро NOUN obl
# мороз NOUN nsubj
# ударил VERB ROOT
# . PUNCT punct
# Градусов NOUN nsubj
# сорок NUM ROOT
# . PUNCT punct
# Руки NOUN nsubj
# - NOUN nsubj
# ноги NOUN nsubj
# у ADP case
# меня PRON obl
# закоченели VERB ROOT
# . PUNCT punct
# Я PRON nsubj
# не PART advmod
# удержался VERB ROOT
# на ADP case
# ветке NOUN obl
# . PUNCT punct
# Бух PROPN ROOT
# вниз ADV advmod
# ! PUNCT punct
# Вся DET det
# волчья ADJ amod
# стая NOUN nsubj
# как ADV advmod
# набросится VERB ROOT
# на ADP case
# меня PRON obl
# ! PUNCT punct
# Что PRON nsubj
# - PRON nsubj
# то PRON nsubj
# как SCONJ mark
# затрещит VERB ROOT
# ! PUNCT punct
#
#
#  SPACE dep
# « PUNCT punct
# Ну PART parataxis
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# думаю VERB parataxis
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# это PART expl
# кости NOUN ROOT
# мои DET det
# трещат PROPN nmod
# » PUNCT punct
# . PUNCT punct
#
#
#  SPACE dep
# А CCONJ cc
# оказывается VERB parataxis
# , PUNCT punct
# это PRON nsubj
# снег NOUN nsubj
# подо ADP case
# мной PRON obl
# провалился VERB ROOT
# . PUNCT punct
# Я PRON ROOT
# как SCONJ mark
# полечу VERB acl
# вниз ADV advmod
# и CCONJ cc
# очутился VERB conj
# в ADP case
# берлоге NOUN obl
# . PUNCT punct
# Внизу ADV parataxis
# , PUNCT punct
# оказывается VERB parataxis
# , PUNCT punct
# медвежья NOUN ROOT
# берлога NOUN nmod
# была AUX cop
# . PUNCT punct
# Медведь NOUN nsubj
# проснулся VERB ROOT
# , PUNCT punct
# выскочил VERB conj
# от ADP case
# испуга NOUN obl
# наружу ADV advmod
# , PUNCT punct
# увидел VERB conj
# волков NOUN obj
# и CCONJ cc
# давай VERB conj
# их PRON obj
# драть VERB xcomp
# . PUNCT punct
# В ADP case
# одну NUM nummod
# минуту NOUN obl
# разогнал VERB ROOT
# всех DET det
# волчишек NOUN obj
# . PUNCT punct
#
#
#  SPACE dep
# Я PRON nsubj
# осмелел VERB ROOT
# , PUNCT punct
# потихоньку ADV advmod
# выглянул VERB advcl
# из ADP case
# берлоги NOUN obl
# . PUNCT punct
# Смотрю VERB ROOT
# : PUNCT punct
# нет VERB parataxis
# волков NOUN nsubj
# – PUNCT punct
# и CCONJ cc
# давай VERB conj
# бежать VERB xcomp
# . PUNCT punct
# Прибежал VERB ROOT
# домой ADV advmod
# , PUNCT punct
# еле PART advmod
# отдышался VERB conj
# . PUNCT punct
# Ну PART parataxis
# , PUNCT punct
# моя DET det
# маменька NOUN nsubj
# дырку NOUN obj
# на ADP case
# штанах NOUN nmod
# зашила VERB ROOT
# , PUNCT punct
# так ADV mark
# что SCONJ fixed
# совсем ADV advmod
# незаметно ADV advmod
# стало VERB advcl
# . PUNCT punct
# А CCONJ cc
# папенька ADJ obj
# , PUNCT punct
# как SCONJ mark
# узнал VERB ccomp
# про ADP case
# этот DET det
# случай NOUN obl
# , PUNCT punct
# так ADV advmod
# сейчас ADV advmod
# же PART advmod
# купил VERB ROOT
# мне PRON iobj
# ружьё NOUN obj
# , PUNCT punct
# чтоб SCONJ mark
# я PRON nsubj
# не PART advmod
# смел VERB advcl
# без ADP case
# ружья NOUN obl
# по ADP case
# лесу NOUN nmod
# шататься VERB xcomp
# . PUNCT punct
# Вот PART advmod
# и PART advmod
# стал VERB ROOT
# я PRON nsubj
# с ADV advmod
# тех DET fixed
# пор NOUN fixed
# охотник NOUN obl
# . PUNCT punct
#
#
#  SPACE dep
# Дядя NOUN nsubj
# Федя PROPN appos
# и CCONJ cc
# дядя NOUN conj
# Кузьма PROPN nmod
# посмеялись VERB ROOT
# над ADP case
# тем PRON obl
# , PUNCT punct
# как SCONJ mark
# дядя NOUN nsubj
# Ваня PROPN appos
# напугался VERB acl
# волков PROPN nsubj
# . PUNCT punct
# А CCONJ cc
# потом ADV advmod
# дядя NOUN nsubj
# Федя PROPN appos
# и CCONJ cc
# говорит VERB ROOT
# : PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
#   SPACE dep
# Я PRON nsubj
# раз NOUN obl
# тоже ADV advmod
# в ADP case
# лесу NOUN obl
# напугался VERB parataxis
# медведя NOUN nsubj
# . PUNCT punct
# Только PART advmod
# это PRON nsubj
# летом NOUN ROOT
# было AUX cop
# . PUNCT punct
# Пошёл VERB ROOT
# я PRON nsubj
# однажды ADV advmod
# в ADP case
# лес NOUN obl
# , PUNCT punct
# а CCONJ cc
# ружьё NOUN nsubj
# дома ADV advmod
# забыл VERB conj
# . PUNCT punct
# Вдруг ADV advmod
# навстречу ADV ROOT
# медведь NOUN nsubj
# . PUNCT punct
# Я PRON nsubj
# от ADP case
# него PRON obl
# бежать VERB ROOT
# . PUNCT punct
# А CCONJ cc
# он PRON nsubj
# за ADP case
# мной PRON ROOT
# . PUNCT punct
# Я PRON nsubj
# бегу VERB ROOT
# быстро ADV advmod
# , PUNCT punct
# ну PART discourse
# а CCONJ cc
# медведь NOUN nsubj
# ещё ADV advmod
# быстрей ADJ conj
# . PUNCT punct
# Слышу VERB advcl
# , PUNCT punct
# уже ADV advmod
# сопит VERB ROOT
# за ADP case
# моей DET det
# спиной NOUN obl
# . PUNCT punct
# Я PRON nsubj
# обернулся VERB ROOT
# , PUNCT punct
# снял VERB conj
# с ADP case
# головы NOUN obl
# шапку NOUN obj
# и CCONJ cc
# бросил VERB conj
# ему PRON iobj
# . PUNCT punct
# Медведь NOUN nsubj
# на ADP case
# минутку NOUN obl
# остановился VERB ROOT
# , PUNCT punct
# обнюхал VERB conj
# шапку NOUN obj
# и CCONJ cc
# опять ADV advmod
# за ADP case
# мной PRON obl
# . PUNCT punct
# Чувствую VERB ROOT
# – PUNCT punct
# опять ADV advmod
# настигает VERB parataxis
# . PUNCT punct
# А CCONJ cc
# до ADP case
# дому NOUN obl
# ещё ADV advmod
# далеко ADV ROOT
# . PUNCT punct
# Снял VERB ROOT
# я PRON nsubj
# на ADP case
#   SPACE dep
# ходу NOUN obl
# куртку NOUN obj
# и CCONJ cc
# бросил VERB conj
# медведю NOUN obj
# . PUNCT punct
#
#
#  SPACE dep
# Думаю VERB ROOT
# : PUNCT punct
# хоть ADV advmod
# на ADP case
# минуточку NOUN obl
# задержу VERB ccomp
# его PRON obj
# . PUNCT punct
#
#
#  SPACE dep
# Ну PART discourse
# , PUNCT punct
# медведь NOUN nsubj
# разодрал VERB ROOT
# куртку NOUN obj
# , PUNCT punct
# видит VERB conj
# – PUNCT punct
# ничего PRON case
# в ADP case
# ней PRON obl
# съедобного ADJ obj
# . PUNCT punct
# Снова ADV advmod
# за ADP case
# мной PRON ROOT
# . PUNCT punct
# Пришлось VERB ROOT
# мне PRON iobj
# бросить VERB csubj
# ему PRON iobj
# и CCONJ cc
# брюки NOUN obj
# , PUNCT punct
# и CCONJ cc
# сапоги NOUN conj
# . PUNCT punct
# Ничего PRON obj
# не PART advmod
# поделаешь VERB ROOT
# : PUNCT punct
# от ADP case
# зверя NOUN obl
# - NOUN obl
# то PRON obl
# надо ADV parataxis
# спасаться VERB csubj
# ! PUNCT punct
#
#
#  SPACE dep
# Выбежал VERB ROOT
# я PRON nsubj
# из ADP case
# леса NOUN obl
# в ADP case
# одной NUM nummod
# майке NOUN nmod
# и CCONJ cc
# трусиках NOUN conj
# . PUNCT punct
# Тут ADV advmod
# впереди ADV ROOT
# речка NOUN nsubj
# и CCONJ cc
# мостик NOUN conj
# через ADP case
# неё PROPN nmod
# . PUNCT punct
# Не PART advmod
# успел VERB ROOT
# я PRON nsubj
# перебежать VERB xcomp
# через ADP case
# мостик NOUN obl
# – PUNCT punct
# как ADV advmod
# затрещит VERB parataxis
# что PRON nsubj
# - PRON nsubj
# то PRON nsubj
# ! PUNCT punct
# Оглянулся VERB ROOT
# я PRON nsubj
# , PUNCT punct
# а CCONJ cc
# это PRON nsubj
# мостик NOUN nsubj
# под ADP case
# медведем NOUN nmod
# рухнул VERB conj
# . PUNCT punct
# Медведь NOUN nsubj
# бултых ADJ ROOT
# в ADP case
# речку NOUN obl
# ! PUNCT punct
#
#
#  SPACE dep
# « PUNCT punct
# Ну PART parataxis
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# думаю VERB parataxis
# , PUNCT punct
#   SPACE dep
# – PUNCT punct
# так ADV advmod
# тебе PRON iobj
# и PART advmod
# надо ADV ROOT
# , PUNCT punct
# бродяга NOUN conj
# , PUNCT punct
# чтоб SCONJ mark
# не PART advmod
# пугал VERB advcl
# людей NOUN obj
# зря ADV advmod
# » PUNCT punct
# . PUNCT punct
#
#
#  SPACE dep
# Только PART advmod
# под ADP case
# мостиком NOUN obl
# было AUX cop
# неглубоко ADJ ROOT
# . PUNCT punct
# Медведь NOUN nsubj
# вылез VERB ROOT
# на ADP case
# берег NOUN obl
# , PUNCT punct
# отряхнулся VERB conj
# как SCONJ mark
# следует VERB obl
# и PART advmod
# в ADP case
# лес NOUN obl
# обратно ADV advmod
# ушёл NOUN obl
# . PUNCT punct
#
#
#  SPACE dep
# А CCONJ cc
# я PRON nsubj
# говорю VERB ROOT
# сам ADJ acl
# себе PRON iobj
# : PUNCT punct
#
#
#  SPACE dep
# « PUNCT punct
# Молодец NOUN parataxis
# , PUNCT punct
# дядя NOUN appos
# Федя PROPN appos
# ! PUNCT punct
# Ловко VERB ROOT
# медведя NOUN obj
# провёл NOUN iobj
# ! PUNCT punct
# Только PART advmod
# как SCONJ fixed
# мне PRON iobj
# теперь ADV advmod
# домой ADV advmod
# идти VERB ROOT
# ? PUNCT punct
# На ADP case
# улице NOUN obl
# люди NOUN nsubj
# увидят VERB ROOT
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# чуть ADV advmod
# ли PART fixed
# не PART advmod
# голышом NOUN ccomp
# , PUNCT punct
# и CCONJ cc
# на ADP case
# смех NOUN obl
# поднимут VERB conj
# » PUNCT punct
# . PUNCT punct
#
#
#  SPACE dep
# И CCONJ cc
# решил VERB ROOT
# : PUNCT punct
# посижу VERB parataxis
# здесь ADV advmod
# в ADP case
# кусточках NOUN obl
# , PUNCT punct
# а CCONJ cc
# стемнеет VERB conj
# , PUNCT punct
# пойду VERB advcl
# потихоньку ADV advmod
# . PUNCT punct
# Спрятался VERB ROOT
# я PRON nsubj
# в ADP case
#   SPACE dep
# кустах NOUN obl
# и CCONJ cc
# сидел VERB conj
# там ADV advmod
# до ADP case
# вечера NOUN obl
# , PUNCT punct
# а CCONJ cc
# потом ADV advmod
# вылез VERB conj
# и CCONJ cc
# стал VERB conj
# пробираться VERB xcomp
# по ADP case
# улицам NOUN obl
# . PUNCT punct
# Как SCONJ mark
# только PART fixed
# увижу VERB ROOT
# , PUNCT punct
# что SCONJ mark
# кто PRON nsubj
# - PRON nsubj
# нибудь PRON nsubj
# идёт VERB ccomp
# навстречу ADV advmod
# , PUNCT punct
# сейчас ADV advmod
# же PART advmod
# шмыгну VERB conj
# куда ADV advmod
# - ADV advmod
# нибудь ADV advmod
# за ADP case
# угол NOUN obl
# и CCONJ cc
# сижу VERB conj
# там ADV advmod
# в ADP case
# потёмках NOUN obl
# , PUNCT punct
# чтоб SCONJ mark
# на ADP case
# глаза NOUN obl
# не PART advmod
# попадаться VERB advcl
# . PUNCT punct
#
#
#
#
#
#  SPACE dep
# Конец NOUN ROOT
# ознакомительного ADJ amod
# фрагмента NOUN nmod
# . PUNCT punct
#
#
#
#  SPACE dep
# Текст NOUN nsubj:pass
# предоставлен VERB ROOT
# ООО PROPN obl:agent
# « PUNCT punct
# ЛитРес NOUN appos
# » PUNCT punct
# . PUNCT punct
#
#
#  SPACE dep
# Прочитайте VERB ROOT
# эту DET det
# книгу NOUN obj
# целиком ADV advmod
# , PUNCT punct
# купив VERB advcl
# полную ADJ amod
# легальную ADJ amod
# версию NOUN obj
# ( PUNCT punct
# https://www.litres.ru/pages/biblio_book/?art=48787077&lfrom=159481197 PROPN appos
# ) PUNCT punct
# на ADP case
# ЛитРес PROPN nmod
# . PUNCT punct
#
#
#  SPACE dep
# Безопасно ADJ ROOT
# оплатить VERB csubj
# книгу NOUN obj
# можно ADV advmod
# банковской ADJ amod
# картой NOUN obl
# Visa PROPN appos
# , PUNCT punct
# MasterCard PROPN conj
# , PUNCT punct
# Maestro PROPN conj
# , PUNCT punct
# со ADP case
# счета NOUN obl
# мобильного ADJ amod
# телефона NOUN nmod
# , PUNCT punct
# с ADP case
# платежного ADJ amod
# терминала NOUN obl
# , PUNCT punct
# в ADP case
# салоне NOUN obl
# МТС PROPN nmod
# или CCONJ cc
# Связной PROPN conj
# , PUNCT punct
# через ADP case
# PayPal PROPN conj
# , PUNCT punct
# WebMoney PROPN conj
# , PUNCT punct
# Яндекс PROPN conj
# . PUNCT punct
# Деньги NOUN nsubj
# , PUNCT punct
# QIWI PROPN conj
# Кошелек PROPN flat:name
# , PUNCT punct
# бонусными ADJ amod
# картами NOUN conj
# или CCONJ cc
# другим ADJ amod
# удобным ADJ amod
# Вам PRON conj
# способом NOUN ROOT
# . PUNCT punct
#
#
#
#  SPACE dep

# %%
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ru" id="5556a3874fdd4f6695af8947ba1e3194-0" class="displacy" width="566175" height="1099.5" direction="ltr" style="max-width: none; height: 1099.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Живая</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">шляпа</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">Николай</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">Николаевич</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">Носов</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">
#
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Классика</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">нашего</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">детства</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">Рассказы,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">как</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">и</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">все</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">произведения</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">Николая</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">Носова,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">давно</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">стали</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">не</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">только</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">классикой,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">но</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">и,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">без</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">преувеличения,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">национальным</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">достоянием.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">В</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1009.5">
#     <tspan class="displacy-word" fill="currentColor" x="5

# %%
nlp = spacy.load('en_core_web_sm')
doc1 = nlp(u'We can overtake them.')
doc2 = nlp(u'You must specify it.')
for i in range(len(doc1)-1):
    if doc1[i].dep_ == doc2[i].dep_:
        print(doc1[i].text,'\t', doc2[i].text, '\t', doc1[i].dep_, spacy.explain(doc1[i].dep_))
# Out:
# We 	 You 	 nsubj nominal subject
# can 	 must 	 aux auxiliary
# overtake 	 specify 	 ROOT root
# them 	 it 	 dobj direct object

# %%
from natasha import Segmenter, NewsEmbedding, NewsSyntaxParser, Doc

# %%
emb = NewsEmbedding()

# %%
segmenter = Segmenter()

# %%
syntax_parser = NewsSyntaxParser(emb)

# %%
text = 'Я подкрался на цыпочках к столу, дёрнул за край одеяла и бегом к двери. '

# %%
doc = Doc(text)

# %%
doc.segment(segmenter)

# %%
for tocken in doc.tokens:
    print(tocken)
# Out:
# DocToken(stop=1, text='Я')
# DocToken(start=2, stop=11, text='подкрался')
# DocToken(start=12, stop=14, text='на')
# DocToken(start=15, stop=23, text='цыпочках')
# DocToken(start=24, stop=25, text='к')
# DocToken(start=26, stop=31, text='столу')
# DocToken(start=31, stop=32, text=',')
# DocToken(start=33, stop=39, text='дёрнул')
# DocToken(start=40, stop=42, text='за')
# DocToken(start=43, stop=47, text='край')
# DocToken(start=48, stop=54, text='одеяла')
# DocToken(start=55, stop=56, text='и')
# DocToken(start=57, stop=62, text='бегом')
# DocToken(start=63, stop=64, text='к')
# DocToken(start=65, stop=70, text='двери')
# DocToken(start=70, stop=71, text='.')

# %%
doc.parse_syntax(syntax_parser)

# %%
for tocken in doc.tokens:
    print(tocken)
# Out:
# DocToken(stop=1, text='Я', id='1_1', head_id='1_2', rel='nsubj')
# DocToken(start=2, stop=11, text='подкрался', id='1_2', head_id='1_0', rel='root')
# DocToken(start=12, stop=14, text='на', id='1_3', head_id='1_4', rel='case')
# DocToken(start=15, stop=23, text='цыпочках', id='1_4', head_id='1_2', rel='obl')
# DocToken(start=24, stop=25, text='к', id='1_5', head_id='1_6', rel='case')
# DocToken(start=26, stop=31, text='столу', id='1_6', head_id='1_8', rel='obl')
# DocToken(start=31, stop=32, text=',', id='1_7', head_id='1_8', rel='punct')
# DocToken(start=33, stop=39, text='дёрнул', id='1_8', head_id='1_6', rel='acl')
# DocToken(start=40, stop=42, text='за', id='1_9', head_id='1_10', rel='case')
# DocToken(start=43, stop=47, text='край', id='1_10', head_id='1_8', rel='obl')
# DocToken(start=48, stop=54, text='одеяла', id='1_11', head_id='1_2', rel='obl')
# DocToken(start=55, stop=56, text='и', id='1_12', head_id='1_13', rel='cc')
# DocToken(start=57, stop=62, text='бегом', id='1_13', head_id='1_11', rel='conj')
# DocToken(start=63, stop=64, text='к', id='1_14', head_id='1_15', rel='case')
# DocToken(start=65, stop=70, text='двери', id='1_15', head_id='1_13', rel='obl')
# DocToken(start=70, stop=71, text='.', id='1_16', head_id='1_2', rel='punct')

# %%
doc.sents[0].syntax.print()
# Out:
#           ┌► Я         nsubj
# ┌─┌─────┌─└─ подкрался
# │ │     │ ┌► на        case
# │ │     └►└─ цыпочках  obl
# │ │       ┌► к         case
# │ │   ┌─┌►└─ столу     obl
# │ │   │ │ ┌► ,         punct
# │ │ ┌─└►└─└─ дёрнул    acl
# │ │ │     ┌► за        case
# │ │ └────►└─ край      obl
# │ └────►┌─── одеяла    obl
# │       │ ┌► и         cc
# │     ┌─└►└─ бегом     conj
# │     │   ┌► к         case
# │     └──►└─ двери     obl
# └──────────► .         punct
