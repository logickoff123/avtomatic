# %%
class Matrix:
    def __init__(self,matrix):
        self.matrix = matrix
        
    # def eq(self, other_matrix):
    #     if len(self.matrix)!= len(other_matrix) or len(self.matrix[0])!=len(other_matrix[0]):
    #         print ("Размерность попутал")
    #         return 0
    #     for i in range(len(self.matrix)):
    #         for J in range (len(self.matrix[0])):
    #             if self.matrix[i][j]!=other_matrix[i][j]:
    #                 return 0
    #     return 1
    
    def __add__ (self, other):
        resultat = [] # создаем пустой список для результат
        if isinstance(other,int) or isinstance(other,float): # проверка на число 
           for line in range(len(self.matrix)):# прогняемся по строчкам
                new_line = [] # создаем пустую строку для новой матрицы 
                for column in range(len(self.matrix[0])): # прогоняемя по столбцам в строчке начиная -> matrix[0]- первый элемнт в матрице  
                    new_line.append (self.matrix[line][column] + other)  # складываем -_-
                resultat.append(new_line) 
        else:
            for line in range(len(self.matrix)):# прогняемся по строчкам
                new_line = [] # создаем пустую строку для новой матрицы
                for column in range(len(self.matrix[0])): # прогоняемя по столбцам в строчке начиная -> matrix[0]- первый элемнт в матрице  
                    new_line.append (self.matrix[line][column] + other.matrix[line][column] )  
                resultat.append(new_line)
        return Matrix(resultat)
    
    # add, sub, truediv и mul работают по такому же принципу просто меняем знак 
    #сколярка и транспонирование работают по другому сейчас объясню
    
    def __sub__ (self, other):
        resultat = []
        if isinstance(other,int) or isinstance(other,float):
           for line in range(len(self.matrix)):# прогняемся по строчкам
                new_line = []
                for column in range(len(self.matrix[0])): # прогоняемя по столбцам в строчке начиная -> matrix[0]- первый элемнт в матрице  
                    new_line.append (self.matrix[line][column] - other)  
                resultat.append(new_line)
        else:
            for line in range(len(self.matrix)):# прогняемся по строчкам
                new_line = []
                for column in range(len(self.matrix[0])): # прогоняемя по столбцам в строчке начиная -> matrix[0]- первый элемнт в матрице 
                    new_line.append (self.matrix[line][column] - other.matrix[line][column] )  
                resultat.append(new_line)
        return Matrix(resultat)
                
                
    def __truediv__ (self, other):
        resultat = []
        if isinstance(other,int) or isinstance(other,float):
           for line in range(len(self.matrix)):# прогняемся по строчкам
                new_line = []
                for column in range(len(self.matrix[0])): # прогоняемя по столбцам в строчке начиная -> matrix[0]- первый элемнт в матрице  
                    new_line.append (self.matrix[line][column] / other)  
                resultat.append(new_line)
        else:
            for line in range(len(self.matrix)):# прогняемся по строчкам
                new_line = []
                for column in range(len(self.matrix[0])): # прогоняемя по столбцам в строчке начиная -> matrix[0]- первый элемнт в матрице 
                    new_line.append (self.matrix[line][column] / other.matrix[line][column] )  
                resultat.append(new_line)
        return Matrix(resultat)            
    
    # сколярка делаеться следующим образом :строка на столбец
    # поэтому сначала проходимся по строчкам в первой потом по столбцам во второй
    # однако строчку на строку мы то умножаем, но не забываем что и строка и столбец
    # состоят из элементов, поэтому нам понадобиться тут три цикла 
    
    
    def __matmul__(self,other):
        resultat = [] # тут по классике создаем список для результата
        for line in range(len(self.matrix)):# прогоняем по строчкам матрицу первую
            new_line = [] # новую матрицу сюда запихнем
            for column in range(len(other.matrix[0])):#прогоняем по столбцам матрицу вторую
                skolar_peremen = 0 # переменная для сколярного произведения  
                for i in range(len(self.matrix[0])): # прогоняем по элементам строки перой матрицы и столбца второй матрицы 
                    skolar_peremen += self.matrix[line][i] * other.matrix[i][column] # сколярка 
                new_line.append(skolar_peremen)
        resultat.append(new_line)
    
        return Matrix(resultat)
    
    def __mul__(self,other):
        resultat = []
        if isinstance(other,int) or isinstance(other,float):
           for line in range(len(self.matrix)):# прогняемся по строчкам
                new_line = []
                for column in range(len(self.matrix[0])): # прогоняемя по столбцам в строчке начиная -> matrix[0]- первый элемнт в матрице  
                    new_line.append (self.matrix[line][column] * other)  
                resultat.append(new_line)
        else:
            for line in range(len(self.matrix)):# прогняемся по строчкам
                new_line = []
                for column in range(len(self.matrix[0])): # прогоняемя по столбцам в строчке начиная -> matrix[0]- первый элемнт в матрице  
                    new_line.append (self.matrix[line][column] * other.matrix[line][column] )  
                resultat.append(new_line)
        return Matrix(resultat)  
    
    # меняем строки и столбцы местами, так как транспонированная матрица начинаеться со столбца, которая была строчкой у первой , то сначала прогоняемся по столбцам
    def T(self):
        resultat = [] # и снова создаем список для результата
        for column in range(len(self.matrix[0])): # прогоняемя по столбцам в строчке начиная -> matrix[0]- первый элемнт в матрице
            new_line = []
            for line in range(len(self.matrix)): # прогоняем по строкам 
                new_line.append(self.matrix[line][column]) # добовляем элемент из столбца в новую строчку 
            resultat.append (new_line)
        return Matrix(resultat)

# %%
# %pip install -q ipytest pytest

import numpy as np
import ipytest
import pytest
ipytest.autoconfig()
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %%ipytest
#
# matrix1 = Matrix([[1,2,3],[1,2,3],[1,2,3]])
# matrix2 = Matrix([[4,5,6],[4,5,6],[4,5,6]])
#
# @pytest.mark.parametrize("matrix1,matrix2", [[matrix1, matrix2]])
# def test_matrix_add_matrix(matrix1: Matrix, matrix2: Matrix):
#     assert (
#         (np.array((matrix1 + matrix2).matrix) == (np.array(matrix1.matrix) + np.array(matrix2.matrix))).all()
#     ), 'add section with matrices is not working right'
#
# @pytest.mark.parametrize("matrix1,number", [[matrix1, 13.2]])
# def test_matrix_add_number(matrix1: Matrix, number: int | float):
#     assert (
#         (np.array((matrix1 + number).matrix) == np.array(matrix1.matrix) + number).all()
#     ), 'add section with matrix and number is not working right'
#
# @pytest.mark.parametrize("matrix1,matrix2", [[matrix1, matrix2]])
# def test_matrix_sub_matrix(matrix1: Matrix, matrix2: Matrix):
#     assert (
#         (np.array((matrix1 - matrix2).matrix) == np.array(matrix1.matrix) - np.array(matrix2.matrix)).all()
#     ), 'sub section with matrices is not working right'
#
# @pytest.mark.parametrize("matrix1,number", [[matrix1, 12.2]])
# def test_matrix_sub_number(matrix1: Matrix, number: int | float):
#     assert (
#         (np.array((matrix1 - number).matrix) == np.array(matrix1.matrix) - number).all()
#     ), 'sub section with matrix and number is not working right'
#
# @pytest.mark.parametrize("matrix1", [matrix1])
# def test_matrix_transpose(matrix1: Matrix):
#     assert (
#         (np.array(matrix1.T().matrix) == np.array(matrix1.matrix).T).all()
#     ), 'transpose section is not working right'
#
# # -----------------------------------------
#
# @pytest.mark.parametrize("matrix1,matrix2", [[matrix1, matrix2]])
# def test_matrix_mul_matrix(matrix1: Matrix, matrix2: Matrix):
#     assert (
#         (np.array((matrix1 * matrix2).matrix) == np.array(matrix1.matrix) * np.array(matrix2.matrix)).all()
#     ), 'mul section with matrices is not working right'
#
# @pytest.mark.parametrize("matrix1,number", [[matrix1, 13]])
# def test_matrix_mul_number(matrix1: Matrix, number: int | float):
#     assert (
#         (np.array((matrix1 * number).matrix) == np.array(matrix1.matrix) * number).all()
#     ), 'mul section with matrix and number is not working right'
#
# @pytest.mark.parametrize("matrix1,matrix2", [[matrix1, matrix2]])
# def test_matrix_div_matrix(matrix1: Matrix, matrix2: Matrix):
#     assert (
#         (np.array((matrix1 / matrix2).matrix) == np.array(matrix1.matrix) / np.array(matrix2.matrix)).all()
#     ), 'div section with matrices is not working right'
#
# @pytest.mark.parametrize("matrix1,number", [[matrix1, 2]])
# def test_matrix_div_number(matrix1: Matrix, number: int | float):
#     assert (
#         (np.array((matrix1 / number).matrix) == np.array(matrix1.matrix) / number).all()
#     ), 'div section with matrix and number is not working right'
#
# @pytest.mark.parametrize("matrix1,matrix2", [[matrix1, matrix2.T()]])
# def test_matrix_matmul_matrix(matrix1: Matrix, matrix2: Matrix):
#     assert(
#         (np.array((matrix1 @ matrix2).matrix) == np.array(matrix1.matrix) @ np.array(matrix2.matrix)).all()
#     ), 'matmul section is not working right, and don\'t forget about T() if needed'
# Out:
# ..........                                                                                   [100%]
# 10 passed in 0.04s
